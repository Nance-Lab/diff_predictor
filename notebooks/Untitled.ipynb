# %%
# libraries used
import boto3
import diff_classifier.aws as aws
import pandas as pd
import seaborn as sn
import numpy as np
import matplotlib.pyplot as pl

from diff_classifier import features

from os import listdir, getcwd, chdir
from os.path import isfile, join
import os

from matplotlib import colors as plt_colors

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing

# %%
if not 'workbookDir' in globals():
    workbookDir = getcwd()
print('Current Notebook Dir: ' + workbookDir)
chdir(workbookDir) # Go to current workbook Dir
chdir('..')        # Go up one
print(f'Using current directory for loading data: {getcwd()}')
workbookDir = getcwd()
# Out:
# Current Notebook Dir: C:\Users\david\Documents\nancework\source\diff_predictor\notebooks
# Using current directory for loading data: C:\Users\david\Documents\nancework\source\diff_predictor

# %%
dataset_path = workbookDir + '/raw_data_region_hippocampus_ganglia_thalamus/'
filelist = [f for f in listdir(dataset_path) if isfile(join(dataset_path, f)) and 'msd_' in f]

# %%
import time
lengths = []
times = []
for file in filelist:
    start = time.time()
    fstats = pd.read_csv(dataset_path + file, encoding = "ISO-8859-1", index_col='Unnamed: 0')
    features.calculate_features(fstats)
    end = time.time()
    lengths.append(len(fstats))
    times.append(end-start)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-e5c08bbbd418> in <module>
#       5     start = time.time()
#       6     fstats = pd.read_csv(dataset_path + file, encoding = "ISO-8859-1", index_col='Unnamed: 0')
# ----> 7     features.calculate_features(fstats)
#       8     end = time.time()
#       9     lengths.append(len(fstats))
#
# C:\ProgramData\Miniconda3\envs\tf-gpu\lib\site-packages\diff_classifier\features.py in calculate_features(dframe, framerate, frame, mean_values)
#     803           datai['Y'][particle])) = aspectratio(single_track)
#     804         (datai['boundedness'][particle], datai['fractal_dim'][particle],
# --> 805          datai['trappedness'][particle]) = boundedness(single_track, framerate)
#     806         (datai['efficiency'][particle],
#     807          datai['straightness'][particle]) = efficiency(single_track)
#
# ...

# %%
len(lengths)
# Out:
# 18

# %%
sum(times)/60
# Out:
# 29.175580684343974

# %%
import time
lengths = []
times = []
for i in range(3):
    for file in filelist:
        start = time.time()
        fstats = pd.read_csv(dataset_path + file, encoding = "ISO-8859-1", index_col='Unnamed: 0')
        features.calculate_features(fstats)
        end = time.time()
        lengths.append(len(fstats))
        times.append(end-start)
        print(np.mean(times))
# Out:
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# Optimal parameters not found. Print NaN instead.
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (1, 67)
# (1, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (4, 67)
# (2, 67)
# (12, 67)
# (3, 67)
# (1, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (1, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (27, 67)
# (3, 67)
# (1, 67)
# (1, 67)
# (1, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (8, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (2, 67)
# (5, 67)
# (8, 67)
# (2, 67)
# (1, 67)
# (1, 67)
# (0, 67)
# (0, 67)
# (4, 67)
# (13, 67)
# (0, 67)
# (0, 67)
# (9, 67)
# (4, 67)
# (0, 67)
# (2, 67)
# (0, 67)
# (0, 67)
# (1, 67)
# (0, 67)
# (0, 67)
# (0, 67)
# (1, 67)
# (2, 67)
# (0, 67)
# (1, 67)
# (0, 67)
# (1, 67)
# (3, 67)
# (0, 67)
# ...

# %%
(np.array(lengths)/(651))
# Out:
# array([ 313.,  533.,  514., 4149., 2148., 3519., 1423., 3429.])

# %%
500*20
# Out:
# 10000

# %%
30*10
# Out:
# 5.0
