# %% [markdown]
# # ECM-MPT Data Analysis

# %% [markdown]
#  The following notebook will go through prediction analysis for the Extracellular-Matrix Multiple Particle Tracking (ECM-MPT) study of pup age in P14, P21, P28, and P35 datasets.

# %% [markdown]
# ## Table of Contents
#
#
#   [1.   Load Data](#1.-load-data)<br />
#   [2.   Analysis](#2.-analysis)<br />
#   [3.   Modelling](#modelling)<br />
#   [4.   Evaluate Results](#evaluate-results)<br />

# %% [markdown]
# ---

# %% [markdown]
# ## 1.   Load Data

# %% [markdown]
# Loading feature dataset from ECM_CSVS folder: p14, p21, p28, data are designated with their repective age while p35 data is designated with NT_brain_2.
#
# There are 15 total videos from each age group.

# %%
# libraries used
import boto3
import diff_classifier.aws as aws
import pandas as pd
import seaborn as sn
import numpy as np
import matplotlib.pyplot as pl


from os import listdir, getcwd
from os.path import isfile, join
import os

from matplotlib import colors as plt_colors

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing

import xgboost as xgb
# from xgboost import cv

import shap

# %%
if not 'workbookDir' in globals():
    workbookDir = os.getcwd()
print('Using Dir for loading: ' + workbookDir)
os.chdir(workbookDir)
# Out:
# Using Dir for loading: /Users/nelsschimek/Documents/Nance Lab/diff_predictor/notebooks

# %%
dataset_path = workbookDir + '/raw_data_age/'
filelist = [f for f in listdir(dataset_path) if isfile(join(dataset_path, f))]

# %%
fstats_tot = None
video_num = 0
for filename in filelist:
    if 'P14' in filename or 'P28' in filename:
        continue
    else:
        try:
            fstats = pd.read_csv(dataset_path + filename, encoding = "ISO-8859-1", index_col='Unnamed: 0')
            print('{} size: {}'.format(filename, fstats.shape))
            if 'P14' in filename:
                raise Exception('P14 not accepted')
    #             fstats['age'] = pd.Series(fstats.shape[0]*[14], index=fstats.index)
            elif 'P21' in filename:
                fstats['age'] = pd.Series(fstats.shape[0]*[21], index=fstats.index)
            elif 'P28' in filename:
                raise Exception('P28 not accepted')
    #             fstats['age'] = pd.Series(fstats.shape[0]*[28], index=fstats.index)
            elif 'NT_brain_2' in filename:
                fstats['age'] = pd.Series(fstats.shape[0]*[35], index=fstats.index)
            else:
                print('Error, no target')
            fstats['Video Number'] = pd.Series(fstats.shape[0]*[video_num], index=fstats.index)
            if fstats_tot is None:
                fstats_tot = fstats
            else:
                fstats_tot = fstats_tot.append(fstats, ignore_index=True)
            video_num += 1
        except Exception:
                print('Skipped!: {}'.format(filename))
# Out:
# features_NT_brain_2_slice_1_vid_4.csv size: (878, 91)
# features_P21_40nm_s2_v1.csv size: (2584, 91)
# features_NT_brain_2_slice_1_vid_5.csv size: (467, 91)
# features_P21_40nm_s2_v3.csv size: (435, 91)
# features_P21_40nm_s2_v2.csv size: (846, 91)
# features_NT_brain_2_slice_1_vid_2.csv size: (833, 91)
# features_NT_brain_2_slice_1_vid_3.csv size: (1017, 91)
# features_NT_brain_2_slice_1_vid_1.csv size: (416, 91)
# features_P21_40nm_s2_v5.csv size: (2884, 91)
# features_P21_40nm_s2_v4.csv size: (1506, 91)
# features_NT_brain_2_slice_2_vid_5.csv size: (2100, 91)
# features_NT_brain_2_slice_2_vid_4.csv size: (1650, 91)
# features_NT_brain_2_slice_2_vid_3.csv size: (1735, 91)
# features_NT_brain_2_slice_2_vid_2.csv size: (2322, 91)
# features_NT_brain_2_slice_2_vid_1.csv size: (2488, 91)
# features_P21_40nm_s3_v2.csv size: (679, 91)
# features_NT_brain_2_slice_3_vid_5.csv size: (1062, 91)
# features_NT_brain_2_slice_3_vid_4.csv size: (598, 91)
# features_P21_40nm_s3_v3.csv size: (456, 91)
# features_P21_40nm_s3_v1.csv size: (1086, 91)
# features_P21_40nm_s1_v4.csv size: (1294, 91)
# features_P21_40nm_s1_v5.csv size: (2540, 91)
# features_P21_40nm_s3_v4.csv size: (1417, 91)
# features_P21_40nm_s1_v1.csv size: (807, 91)
# features_NT_brain_2_slice_3_vid_3.csv size: (817, 91)
# features_NT_brain_2_slice_3_vid_2.csv size: (853, 91)
# features_P21_40nm_s3_v5.csv size: (915, 91)
# features_P21_40nm_s1_v2.csv size: (2481, 91)
# features_NT_brain_2_slice_3_vid_1.csv size: (562, 91)
# features_P21_40nm_s1_v3.csv size: (1330, 91)

# %%
fstats_tot.head()
# Out:
#    Track_ID     alpha      D_fit  kurtosis  asymmetry1  asymmetry2  \
# 0       0.0  0.115809   0.247073  3.037482    0.163388    0.651372
# 1       1.0  1.530304   6.688461  2.453143    0.909885    0.153639
# 2       2.0  3.515488   0.111858  4.164586    0.377209    0.488901
# 3       3.0  0.193469   0.412770  2.691301    0.349696    0.506748
# 4       4.0  0.898500  33.239411  1.477944    0.994335    0.037687
#
#    asymmetry3        AR  elongation  boundedness  ...  Mean convex_hull_norm  \
# 0    0.022537  1.370876    0.270539     0.064241  ...                    0.0
# 1    0.313502  2.561596    0.609618     0.035318  ...                    0.0
# 2    0.060725  1.677507    0.403877     0.221368  ...                    0.0
# 3    0.055072  1.143772    0.125700     0.178531  ...                    0.0
# 4    0.562121  4.343604    0.769776     0.083010  ...                    0.0
#
#    Std convex_hull_norm  Mean dist_tot   Std dist_tot  Mean dist_net  \
# 0                   0.0  330734.138554  557961.813504    2209.743996
# 1                   0.0  330734.138554  557961.813504    2209.743996
# 2                   0.0   49178.846204   28202.615381    2418.440266
# 3                   0.0   48893.186069   29131.903254    2384.502626
# 4                   0.0   44963.732933   24639.451903    2545.410067
#
#    Std dist_net  Mean progression  Std progression  age  Video Number
# 0     16.532443          0.046747         0.037469   35             0
# 1     16.532443          0.046747         0.037469   35             0
# 2     29.054807          0.064635         0.030691   35             0
# 3      1.478225          0.069588         0.036595   35             0
# 4     37.192675          0.076090         0.037673   35             0
#
# [5 rows x 93 columns]

# %% [markdown]
# ## 2.   Analysis

# %% [markdown]
# The following columns are present within the downloaded datasets:

# %%
fstats_tot.columns
# Out:
# Index(['Track_ID', 'alpha', 'D_fit', 'kurtosis', 'asymmetry1', 'asymmetry2',
#        'asymmetry3', 'AR', 'elongation', 'boundedness', 'fractal_dim',
#        'trappedness', 'efficiency', 'straightness', 'MSD_ratio', 'frames', 'X',
#        'Y', 'Quality', 'Mean_Intensity', 'SN_Ratio', 'Deff1', 'Deff2',
#        'angle_mean', 'angle_mag_mean', 'angle_var', 'convex_hull',
#        'convex_hull_norm', 'dist_tot', 'dist_net', 'progression', 'Mean alpha',
#        'Std alpha', 'Mean D_fit', 'Std D_fit', 'Mean kurtosis', 'Std kurtosis',
#        'Mean asymmetry1', 'Std asymmetry1', 'Mean asymmetry2',
#        'Std asymmetry2', 'Mean asymmetry3', 'Std asymmetry3', 'Mean AR',
#        'Std AR', 'Mean elongation', 'Std elongation', 'Mean boundedness',
#        'Std boundedness', 'Mean fractal_dim', 'Std fractal_dim',
#        'Mean trappedness', 'Std trappedness', 'Mean efficiency',
#        'Std efficiency', 'Mean straightness', 'Std straightness',
#        'Mean MSD_ratio', 'Std MSD_ratio', 'Mean frames', 'Std frames',
#        'Mean X', 'Std X', 'Mean Y', 'Std Y', 'Mean Quality', 'Std Quality',
#        'Mean Mean_Intensity', 'Std Mean_Intensity', 'Mean SN_Ratio',
#        'Std SN_Ratio', 'Mean Deff1', 'Std Deff1', 'Mean Deff2', 'Std Deff2',
#        'Mean angle_mean', 'Std angle_mean', 'Mean angle_mag_mean',
#        'Std angle_mag_mean', 'Mean angle_var', 'Std angle_var',
#        'Mean convex_hull', 'Std convex_hull', 'Mean convex_hull_norm',
#        'Std convex_hull_norm', 'Mean dist_tot', 'Std dist_tot',
#        'Mean dist_net', 'Std dist_net', 'Mean progression', 'Std progression',
#        'age', 'Video Number'],
#       dtype='object')

# %% [markdown]
# Many of these features are not useful for prediction or have data which may negatively impact classification. The following features and the target feature are defined in the following cell. We also remove any datapoints that are empty or infinite:

# %%
fstats_tot
features = [
    'alpha', # Fitted anomalous diffusion alpha exponenet
    'D_fit', # Fitted anomalous diffusion coefficient
    'kurtosis', # Kurtosis of track
    'asymmetry1', # Asymmetry of trajecory (0 for circular symmetric, 1 for linear)
    'asymmetry2', # Ratio of the smaller to larger principal radius of gyration
    'asymmetry3', # An asymmetric feature that accnts for non-cylindrically symmetric pt distributions
    'AR', # Aspect ratio of long and short side of trajectory's minimum bounding rectangle
    'elongation', # Est. of amount of extension of trajectory from centroid
    'boundedness', # How much a particle with Deff is restricted by a circular confinement of radius r
    'fractal_dim', # Measure of how complicated a self similar figure is
    'trappedness', # Probability that a particle with Deff is trapped in a region
    'efficiency', # Ratio of squared net displacement to the sum of squared step lengths
    'straightness', # Ratio of net displacement to the sum of squared step lengths
    'MSD_ratio', # MSD ratio of the track
    'frames', # Number of frames the track spans
    'Deff1', # Effective diffusion coefficient at 0.33 s
    'Deff2', # Effective diffusion coefficient at 3.3 s
    'angle_mean', # Mean turning angle which is counterclockwise angle from one frame point to another
    'angle_mag_mean', # Magnitude of the turning angle mean
    'angle_var', # Variance of the turning angle
    'dist_tot', # Total distance of the trajectory
    'dist_net', # Net distance from first point to last point
    'progression', # Ratio of the net distance traveled and the total distance
    'Mean alpha', 
    'Mean D_fit', 
    'Mean kurtosis', 
    'Mean asymmetry1', 
    'Mean asymmetry2',
    'Mean asymmetry3', 
    'Mean AR',
    'Mean elongation', 
    'Mean boundedness',
    'Mean fractal_dim', 
    'Mean trappedness', 
    'Mean efficiency',
    'Mean straightness', 
    'Mean MSD_ratio', 
    'Mean Deff1', 
    'Mean Deff2',
    ]

target = 'age'           # prediction target (y)

ecm = fstats_tot
ecm = ecm[~ecm.isin([np.nan, np.inf, -np.inf]).any(1)]       # Removing nan and inf data points

# %%
# Showing a piece of our data:
ecm.head()
# Out:
#    Track_ID     alpha      D_fit  kurtosis  asymmetry1  asymmetry2  \
# 0       0.0  0.115809   0.247073  3.037482    0.163388    0.651372
# 1       1.0  1.530304   6.688461  2.453143    0.909885    0.153639
# 2       2.0  3.515488   0.111858  4.164586    0.377209    0.488901
# 3       3.0  0.193469   0.412770  2.691301    0.349696    0.506748
# 4       4.0  0.898500  33.239411  1.477944    0.994335    0.037687
#
#    asymmetry3        AR  elongation  boundedness  ...  Mean convex_hull_norm  \
# 0    0.022537  1.370876    0.270539     0.064241  ...                    0.0
# 1    0.313502  2.561596    0.609618     0.035318  ...                    0.0
# 2    0.060725  1.677507    0.403877     0.221368  ...                    0.0
# 3    0.055072  1.143772    0.125700     0.178531  ...                    0.0
# 4    0.562121  4.343604    0.769776     0.083010  ...                    0.0
#
#    Std convex_hull_norm  Mean dist_tot   Std dist_tot  Mean dist_net  \
# 0                   0.0  330734.138554  557961.813504    2209.743996
# 1                   0.0  330734.138554  557961.813504    2209.743996
# 2                   0.0   49178.846204   28202.615381    2418.440266
# 3                   0.0   48893.186069   29131.903254    2384.502626
# 4                   0.0   44963.732933   24639.451903    2545.410067
#
#    Std dist_net  Mean progression  Std progression  age  Video Number
# 0     16.532443          0.046747         0.037469   35             0
# 1     16.532443          0.046747         0.037469   35             0
# 2     29.054807          0.064635         0.030691   35             0
# 3      1.478225          0.069588         0.036595   35             0
# 4     37.192675          0.076090         0.037673   35             0
#
# [5 rows x 93 columns]

# %% [markdown]
# Before prediction, it is required to balance data. As shown, The current dataset is highly imbalance with most datapoints belonging to P21 and P35 categories. The dataset is reduced using random sampling of each target category.

# %%
#--------------NOT-ADDED-----------------------------
def balance_data(df, target, **kwargs):
    if 'random_state' not in kwargs:
        random_state = 1
    else:
        random_state = kwargs['random_state']
    df_target = []
    bal_df = []
    for name in df[target].unique():
        df_target.append((name, df[df[target] == name]))
    print(f"Ratio before data balance ({':'.join([str(i[0]) for i in df_target])}) = {':'.join([str(len(i[1])) for i in df_target])}")
    for i in range(len(df_target)):
        ratio = min([len(i[1]) for i in df_target])/len(df_target[i][1])
        bal_df.append(df_target[i][1].sample(frac=ratio, random_state=random_state))
    print(f"Ratio after balance ({':'.join([str(i[0]) for i in df_target])}) = {':'.join([str(len(i)) for i in bal_df])}")
    return pd.concat(bal_df)
bal_ecm = balance_data(ecm, target, random_state=1)
# Out:
# Ratio before data balance (35:21) = 17169:20665
# Ratio after balance (35:21) = 17169:17169

# %%
# ecm_14 = ecm[ecm[target] == 14]
# ecm_21 = ecm[ecm[target] == 21]
# ecm_28 = ecm[ecm[target] == 28]
# ecm_35 = ecm[ecm[target] == 35]
# print(f"Ratio before data balance (P14:P21:P28:P35) = {len(ecm_14)}:{len(ecm_21)}:{len(ecm_28)}:{len(ecm_35)}")
# ecm_list = [ecm_14, ecm_21, ecm_28, ecm_35]
# for i in range(len(ecm_list)):
#     ratio = min([len(i) for i in ecm_list])/len(ecm_list[i])
#     ecm_list[i] = ecm_list[i].sample(frac=ratio, random_state=1)
# print(f"Ratio after balance (P14:P21:P28:P35) = {len(ecm_list[0])}:{len(ecm_list[1])}:{len(ecm_list[2])}:{len(ecm_list[3])}")
# bal_ecm = pd.concat(ecm_list)

# %% [markdown]
# ## 3.   Modelling

# %% [markdown]
# The model used for this study is an extreme gradient boosting (XGBoost) decision tree which is a boosted decision tree. This model was used due to its past results within competitions and research.

# %% [markdown]
# Due to the use of statistical surroundings in our feature analysis, binning is required in order to avoid data leakage between training/testing. The followingcode will implement binning and a checkerboard implementation to select certain bins for the training dataset.

# %%
# Using checkerboard binning for data split:
def checkerboard(size):
    rows = int(size/2)
    checks = list(range(0, size*size, size+1))
    for i in range(1, rows):
        ssize = size - 2*i
        for j in range(0, ssize):
            checks.append(2*i + (size+1)*j)
    for i in range(1, rows):
        ssize = size - 2*i
        for j in range(0, ssize):
            checks.append(size*size - 1 - (2*i + (size+1)*j))
    checks.sort()
    return checks

# %%
# Old method
# bins = list(range(0, 2048+1, 256))
# bal_ecm['binx'] = pd.cut(bal_ecm.X, bins, labels=[0, 1, 2, 3, 4, 5, 6, 7], include_lowest=True)
# bal_ecm['biny'] = pd.cut(bal_ecm.Y, bins, labels=[0, 1, 2, 3, 4, 5, 6, 7], include_lowest=True)
# bal_ecm['bins'] = 8*bal_ecm['binx'].astype(np.int8) + bal_ecm['biny'].astype(np.int8)
# bal_ecm = bal_ecm[np.isfinite(bal_ecm['bins'])]
# bal_ecm['bins'] = bal_ecm['bins'].astype(int)

# cols = bal_ecm.columns.tolist()
# cols = cols[-3:] + cols[:-3]
# bal_ecm = bal_ecm[cols]

# %%
len(bal_ecm.X)/128
# Out:
# 268.265625

# %%
# def bin_data(data, ):
#     pass

resolution = 128
assert not 2048%resolution and resolution >= 128, "resolution needs to be a factor of 2048 and > 128"
bins = list(range(0, 2048+1, resolution))
bin_labels = [int(i/resolution) for i in bins][:-1]
bal_ecm['binx'] = pd.cut(bal_ecm.X, bins, labels=bin_labels, include_lowest=True)
bal_ecm['biny'] = pd.cut(bal_ecm.Y, bins, labels=bin_labels, include_lowest=True)
bal_ecm = bal_ecm[~bal_ecm[['binx', 'biny']].isin([np.nan, np.inf, -np.inf]).any(1)]
bal_ecm['bins'] = (len(bins)-1)*bal_ecm['binx'].astype(np.int32) + bal_ecm['biny'].astype(np.int32)
bal_ecm = bal_ecm[~bal_ecm[['bins']].isin([np.nan, np.inf, -np.inf]).any(1)]
bal_ecm['bins'] = bal_ecm['bins'].astype(int)

# cols = bal_ecm.columns.tolist()
# cols = cols[-3:] + cols[:-3]
# bal_ecm = bal_ecm[cols]

# %%
# Checkerboard method
# seed = 1234
# np.random.seed(seed)
# test_val_split = 0.5

# le = preprocessing.LabelEncoder()
# bal_ecm['encoded_target'] = le.fit_transform(bal_ecm[target])
# X_train = bal_ecm[~bal_ecm.bins.isin(checkerboard((len(bins)-1)))].reset_index()
# X_test_val =  bal_ecm[bal_ecm.bins.isin(checkerboard((len(bins)-1)))].reset_index()
# y_train = X_train['encoded_target']
# X_val, X_test = train_test_split(X_test_val, test_size=test_val_split, random_state=seed)
# y_test = X_test['encoded_target']
# y_val = X_val['encoded_target']
# dtrain = xgb.DMatrix(X_train[features], label=y_train)
# dtest = xgb.DMatrix(X_test[features], label=y_test)
# dval = xgb.DMatrix(X_val[features], label=y_val)

# %%
# Regular split

seed = 1234
np.random.seed(seed)
train_split = 0.6
test_split = 0.5

le = preprocessing.LabelEncoder()
bal_ecm['encoded_target'] = le.fit_transform(bal_ecm[target])
training_bins = np.random.choice(bal_ecm.bins.unique(), int(len(bal_ecm.bins.unique())*train_split), replace=False)
X_train = bal_ecm[bal_ecm.bins.isin(training_bins)]
X_test_val = bal_ecm[~bal_ecm.bins.isin(training_bins)]
if test_split == 1.0:
    X_test = X_test_val
else:
    X_val, X_test = train_test_split(X_test_val, test_size=test_split, random_state=seed)
    y_val = X_val['encoded_target']
y_train = X_train['encoded_target']
y_test = X_test['encoded_target']
dtrain = xgb.DMatrix(X_train[features], label=y_train)
dtest = xgb.DMatrix(X_test[features], label=y_test)
dval = xgb.DMatrix(X_val[features], label=y_val)

# %%
#Check lengths of datasets:
def get_lengths(df, X_train, X_test, X_val=None):
    print(f'Tot before split: {len(df)}')
    print(f'Training: {len(X_train)} ({len(X_train)/len(bal_ecm):.3f}%)')
    print(f'Testing: {len(X_test)} ({len(X_test)/len(bal_ecm):.3f}%)')
    if X_val is not None:
        print(f'Evaluation: {len(X_val)} ({len(X_val)/len(bal_ecm):.3f}%)')
get_lengths(bal_ecm, X_train, X_test, X_val)
# Out:
# Tot before split: 34337
# Training: 20348 (0.593%)
# Testing: 6995 (0.204%)
# Evaluation: 6994 (0.204%)

# %% [markdown]
# Model parameters are based on the best possible XGBoost parameters to minimize logloss error.

# %%
# Init_params for binary logistic classification
init_param = {'max_depth': 3,
              'eta': 0.005,
              'min_child_weight': 0,
              'verbosity': 0,
              'objective': 'binary:logistic',
              'silent': 'True',
              'gamma': 5,
              'subsample': 0.15,
              'colsample_bytree': 0.8,
              'eval_metric': 'logloss'}

# %%
# from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# model = XGBClassifier()

# %%
# model.predict(X_test[features])

# %%
features
# Out:
# ['alpha',
#  'D_fit',
#  'kurtosis',
#  'asymmetry1',
#  'asymmetry2',
#  'asymmetry3',
#  'AR',
#  'elongation',
#  'boundedness',
#  'fractal_dim',
#  'trappedness',
#  'efficiency',
#  'straightness',
#  'MSD_ratio',
#  'frames',
#  'Deff1',
#  'Deff2',
#  'angle_mean',
#  'angle_mag_mean',
#  'angle_var',
#  'dist_tot',
#  'dist_net',
#  'progression',
#  'Mean alpha',
#  'Mean D_fit',
#  'Mean kurtosis',
#  'Mean asymmetry1',
#  'Mean asymmetry2',
#  'Mean asymmetry3',
#  'Mean AR',
#  'Mean elongation',
#  'Mean boundedness',
#  'Mean fractal_dim',
#  'Mean trappedness',
#  'Mean efficiency',
#  'Mean straightness',
#  'Mean MSD_ratio',
#  'Mean Deff1',
#  'Mean Deff2']

# %%
from xgboost.training import CVPack
from xgboost import callback
from xgboost.core import CallbackEnv
from xgboost.core import EarlyStopException

def cv(params, X_train, y_train, features=None, num_boost_round=20, nfold=3, stratified=False, folds=None,
       metrics=(), obj=None, feval=None, maximize=False, early_stopping_rounds=None,
       fpreproc=None, as_pandas=True, verbose_eval=None, show_stdv=True,
       seed=0, callbacks=None, shuffle=True):
    # pylint: disable = invalid-name
    """Cross-validation with given parameters.

    Parameters
    ----------
    params : dict
        Booster params.
    dtrain : DMatrix
        Data to be trained.
    num_boost_round : int
        Number of boosting iterations.
    nfold : int
        Number of folds in CV.
    stratified : bool
        Perform stratified sampling.
    folds : a KFold or StratifiedKFold instance or list of fold indices
        Sklearn KFolds or StratifiedKFolds object.
        Alternatively may explicitly pass sample indices for each fold.
        For ``n`` folds, **folds** should be a length ``n`` list of tuples.
        Each tuple is ``(in,out)`` where ``in`` is a list of indices to be used
        as the training samples for the ``n`` th fold and ``out`` is a list of
        indices to be used as the testing samples for the ``n`` th fold.
    metrics : string or list of strings
        Evaluation metrics to be watched in CV.
    obj : function
        Custom objective function.
    feval : function
        Custom evaluation function.
    maximize : bool
        Whether to maximize feval.
    early_stopping_rounds: int
        Activates early stopping. Cross-Validation metric (average of validation
        metric computed over CV folds) needs to improve at least once in
        every **early_stopping_rounds** round(s) to continue training.
        The last entry in the evaluation history will represent the best iteration.
        If there's more than one metric in the **eval_metric** parameter given in
        **params**, the last metric will be used for early stopping.
    fpreproc : function
        Preprocessing function that takes (dtrain, dtest, param) and returns
        transformed versions of those.
    as_pandas : bool, default True
        Return pd.DataFrame when pandas is installed.
        If False or pandas is not installed, return np.ndarray
    verbose_eval : bool, int, or None, default None
        Whether to display the progress. If None, progress will be displayed
        when np.ndarray is returned. If True, progress will be displayed at
        boosting stage. If an integer is given, progress will be displayed
        at every given `verbose_eval` boosting stage.
    show_stdv : bool, default True
        Whether to display the standard deviation in progress.
        Results are not affected, and always contains std.
    seed : int
        Seed used to generate the folds (passed to numpy.random.seed).
    callbacks : list of callback functions
        List of callback functions that are applied at end of each iteration.
        It is possible to use predefined callbacks by using
        :ref:`Callback API <callback_api>`.
        Example:

        .. code-block:: python

            [xgb.callback.reset_learning_rate(custom_rates)]
    shuffle : bool
        Shuffle data before creating folds.

    Returns
    -------
    evaluation history : list(string)
    """
    if stratified is True and not SKLEARN_INSTALLED:
        raise XGBoostError('sklearn needs to be installed in order to use stratified cv')
    if isinstance(metrics, str):
        metrics = [metrics]
    if not features:
        features = X_train.columns
    if isinstance(params, list):
        _metrics = [x[1] for x in params if x[0] == 'eval_metric']
        params = dict(params)
        if 'eval_metric' in params:
            params['eval_metric'] = _metrics
    else:
        params = dict((k, v) for k, v in params.items())
    if (not metrics) and 'eval_metric' in params:
        if isinstance(params['eval_metric'], list):
            metrics = params['eval_metric']
        else:
            metrics = [params['eval_metric']]
    params.pop("eval_metric", None)
    results = {}
    # create folds in data
    cvfolds, wt_list = mknfold(X_train, y_train, nfold, params, metrics, features)
    
    # setup callbacks
    callbacks = [] if callbacks is None else callbacks
    if early_stopping_rounds is not None:
        callbacks.append(callback.early_stop(early_stopping_rounds,
                                             maximize=maximize,
                                             verbose=False))
    if isinstance(verbose_eval, bool) and verbose_eval:
        callbacks.append(callback.print_evaluation(show_stdv=show_stdv))
    elif isinstance(verbose_eval, int):
        callbacks.append(callback.print_evaluation(verbose_eval, show_stdv=show_stdv))
    callbacks_before_iter = [
        cb for cb in callbacks if
        cb.__dict__.get('before_iteration', False)]
    callbacks_after_iter = [
        cb for cb in callbacks if
        not cb.__dict__.get('before_iteration', False)]
    for i in range(num_boost_round):
        for cb in callbacks_before_iter:
            cb(CallbackEnv(model=None,
                           cvfolds=cvfolds,
                           iteration=i,
                           begin_iteration=0,
                           end_iteration=num_boost_round,
                           rank=0,
                           evaluation_result_list=None))
        for fold in cvfolds:
            fold.update(i, obj)
        res = aggcv([f.eval(i, feval) for f in cvfolds], wt_list)
        for key, mean, std in res:
            if key + '-mean' not in results:
                results[key + '-mean'] = []
            if key + '-std' not in results:
                results[key + '-std'] = []
            results[key + '-mean'].append(mean)
            results[key + '-std'].append(std)
        try:
            for cb in callbacks_after_iter:
                cb(CallbackEnv(model=None,
                               cvfolds=cvfolds,
                               iteration=i,
                               begin_iteration=0,
                               end_iteration=num_boost_round,
                               rank=0,
                               evaluation_result_list=res))
        except EarlyStopException as e:
            for k in results:
                results[k] = results[k][:(e.best_iteration + 1)]
            break
    
    if as_pandas:
        try:
            import pandas as pd
            results = pd.DataFrame.from_dict(results)
        except ImportError:
            pass
    return results

# %%
def bin_fold(X_train, nfold):
    bin_list = [X_train[X_train['bins'] == i_bin].index.to_numpy() for i_bin in X_train.bins.unique()]
    bin_list = sorted(bin_list, key=len)
    i = 0
    while(len(bin_list) > nfold):
        if (i >= len(bin_list)-1):
            i = 0
        bin_list[i] = np.concatenate([bin_list[i], bin_list.pop()])
        i += 1
    wt_list = [len(i)/sum(len(s) for s in bin_list) for i in bin_list]
    return bin_list, wt_list

def mknfold(X_train, y_train, nfold, param, evals=(), features=None):
    if not features:
        features = X_train.columns
    dall = xgb.DMatrix(X_train[features], label=y_train)
    out_idset, wt_list = bin_fold(X_train, nfold)
    in_idset = [np.concatenate([out_idset[i] for i in range(nfold) if k != i]) for k in range(nfold)]
    evals = list(evals)
    ret = []
    for k in range(nfold):
        # perform the slicing using the indexes determined by the above methods
        x_train_snip = X_train.loc[in_idset[k]][features]
        y_train_snip = X_train.loc[in_idset[k]]['encoded_target']        
        x_test_snip = X_train.loc[out_idset[k]][features]
        y_test_snip = X_train.loc[out_idset[k]]['encoded_target']
        dtrain = xgb.DMatrix(x_train_snip, label=y_train_snip)
        dtest = xgb.DMatrix(x_test_snip, label=y_test_snip)
        tparam = param
        plst = list(tparam.items()) + [('eval_metric', itm) for itm in evals]
        ret.append(CVPack(dtrain, dtest, plst))
    return ret, wt_list

# %%
from xgboost.core import STRING_TYPES

def aggcv(rlist, wt_list):
    # pylint: disable=invalid-name
    """
    Aggregate cross-validation results.

    If verbose_eval is true, progress is displayed in every call. If
    verbose_eval is an integer, progress will only be displayed every
    `verbose_eval` trees, tracked via trial.
    """
    cvmap = {}
    idx = rlist[0].split()[0]
    for line in rlist:
        arr = line.split()
        assert idx == arr[0]
        for metric_idx, it in enumerate(arr[1:]):
            if not isinstance(it, STRING_TYPES):
                it = it.decode()
            k, v = it.split(':')
            if (metric_idx, k) not in cvmap:
                cvmap[(metric_idx, k)] = []
            cvmap[(metric_idx, k)].append(float(v))
    msg = idx
    results = []
    for (metric_idx, k), v in sorted(cvmap.items(), key=lambda x: x[0][0]):
        v = np.array(v)
        if not isinstance(msg, STRING_TYPES):
            msg = msg.decode()
        mean = np.average(v, weights=wt_list)
        std = np.average((v-mean)**2, weights=wt_list)
        results.extend([(k, mean, std)])
    return results

# %%
seed = 1234
np.random.seed(seed)

# %%
import operator
import numpy as np

def xgb_paramsearch(X_train, y_train, features, init_params, nfold=5, num_boost_round=2000, early_stopping_rounds=3, metrics=None, **kwargs):
    params = {**init_params}
    if 'use_gpu' in kwargs and kwargs['use_gpu']:
        # GPU integration will cut cv time in ~half:
        params.update({'gpu_id' : 0,
                       'tree_method': 'gpu_hist',
                       'predictor': 'gpu_predictor'})
    if 'metrics' not in kwargs:
        metrics = {params['eval_metric']}
    else:
        metrics.add(params['eval_metric'])
    if params['eval_metric'] in ['map', 'auc', 'aucpr']:
        eval_f = operator.gt
    else: 
        eval_f = operator.lt
    if 'early_break' not in kwargs:
        early_break = 5
    else: 
        early_break = kwargs['early_break']
    if 'thresh' not in kwargs:
        thresh = 0.01
    else: 
        thresh = kwargs['thresh']
    if 'seed' not in kwargs:
        seed = 1111
    else: 
        seed = kwargs['seed']
    best_param = params
    best_model = cv(params, 
                    X_train, 
                    y_train, 
                    features, 
                    nfold=nfold, 
                    num_boost_round=num_boost_round, 
                    early_stopping_rounds=early_stopping_rounds, 
                    metrics=metrics)
    best_eval = best_model[f"test-{params['eval_metric']}-mean"].min()
    best_boost_rounds = best_model[f"test-{params['eval_metric']}-mean"].idxmin()
    
    def _gs_helper(var1n, var2n, best_model, best_param, best_eval, best_boost_rounds):
        local_param = {**best_param}
        for var1, var2 in gs_params:
            print(f"Using CV with {var1n}={{{var1}}}, {var2n}={{{var2}}}")
            local_param[var1n] = var1
            local_param[var2n] = var2
            cv_model = cv(local_param, 
                          X_train, 
                          y_train, 
                          features, 
                          nfold=nfold, 
                          num_boost_round= num_boost_round, 
                          early_stopping_rounds=early_stopping_rounds, 
                          metrics=metrics)
            cv_eval = cv_model[f"test-{local_param['eval_metric']}-mean"].min()
            boost_rounds = cv_model[f"test-{local_param['eval_metric']}-mean"].idxmin()
            if(eval_f(cv_eval, best_eval)):
                best_model = cv_model
                best_param[var1n] = var1
                best_param[var2n] = var2
                best_eval = cv_eval
                best_boost_rounds = boost_rounds
                print(f"New best param found: "
                      f"{local_param['eval_metric']} = {{{best_eval}}}, "
                      f"boost_rounds = {{{best_boost_rounds}}}")
        return best_model, best_param, best_eval, best_boost_rounds
    
    while(early_break >= 0):
        np.random.seed(seed)
        best_eval_init = best_eval
        gs_params = {
            (subsample, colsample)
            for subsample in np.random.choice([i/10. for i in range(5,11)], 3)
            for colsample in np.random.choice([i/10. for i in range(5,11)], 3)
        }
        best_model, best_param, best_eval, best_boost_rounds = _gs_helper('subsample', 
                                                                          'colsample_bytree', 
                                                                          best_model, 
                                                                          best_param, 
                                                                          best_eval, 
                                                                          best_boost_rounds)
        gs_params = {
            (max_depth, min_child_weight)
            for max_depth in [10] + list(np.random.randint(1, 10, 3))
            for min_child_weight in [0, 10] + list(np.random.randint(0, 10, 3))
        }
        best_model, best_param, best_eval, best_boost_rounds = _gs_helper('max_depth', 
                                                                          'min_child_weight', 
                                                                          best_model, 
                                                                          best_param, 
                                                                          best_eval, 
                                                                          best_boost_rounds)
        gs_params = {
            (eta, gamma)
            for eta in np.random.choice([.005, .01, .05, .1, .2, .3], 3)
            for gamma in [0] + list(np.random.choice([0.01, 0.001, 0.2, 0.5, 1.0, 2.0, 3.0, 5.0, 10.0], 3))
        }
        best_model, best_param, best_eval, best_boost_rounds = _gs_helper('eta', 
                                                                          'gamma', 
                                                                          best_model, 
                                                                          best_param, 
                                                                          best_eval, 
                                                                          best_boost_rounds)
        if (abs(best_eval_init - best_eval) < thresh):
            early_break-=1
        seed+=1
    return best_model, best_param, best_eval, best_boost_rounds

# %%
seed=1000
# best_model, best_param, best_eval, best_boost_rounds = xgb_paramsearch(X_train, y_train, features, init_params=init_param, nfold=5, num_boost_round=2000, early_stopping_rounds=3, metrics={'mlogloss', 'merror'}, use_gpu='True', seed=seed)

best_model, best_param, best_eval, best_boost_rounds = xgb_paramsearch(X_train, y_train, features, init_params=init_param, nfold=5, num_boost_round=10, early_stopping_rounds=3, metrics={'mlogloss', 'merror'}, seed=seed)
# Out:
# Using CV with subsample={0.8}, colsample_bytree={1.0}
# Using CV with subsample={0.5}, colsample_bytree={1.0}
# Using CV with subsample={0.5}, colsample_bytree={0.5}
# Using CV with subsample={0.8}, colsample_bytree={0.9}
# Using CV with subsample={0.5}, colsample_bytree={0.6}
# Using CV with subsample={0.8}, colsample_bytree={0.6}
# Using CV with subsample={0.8}, colsample_bytree={0.5}
# Using CV with max_depth={10}, min_child_weight={8}
# New best param found: logloss = {0.681762553273049}, boost_rounds = {9}
# Using CV with max_depth={5}, min_child_weight={4}
# New best param found: logloss = {0.6817130856595243}, boost_rounds = {9}
# Using CV with max_depth={5}, min_child_weight={10}
# New best param found: logloss = {0.6816577041969727}, boost_rounds = {9}
# Using CV with max_depth={5}, min_child_weight={5}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={5}, min_child_weight={0}
# New best param found: logloss = {0.6815916581482209}, boost_rounds = {9}
# Using CV with max_depth={10}, min_child_weight={0}
# New best param found: logloss = {0.6813124667289168}, boost_rounds = {9}
# Using CV with max_depth={5}, min_child_weight={2}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with max_depth={10}, min_child_weight={2}
# Using CV with eta={0.3}, gamma={1.0}
# New best param found: logloss = {0.6124428847061136}, boost_rounds = {3}
# Using CV with eta={0.05}, gamma={0}
# New best param found: logloss = {0.6119390517987026}, boost_rounds = {9}
# Using CV with eta={0.3}, gamma={0}
# New best param found: logloss = {0.611924197955573}, boost_rounds = {4}
# Using CV with eta={0.2}, gamma={0}
# New best param found: logloss = {0.5941571433064674}, boost_rounds = {7}
# Using CV with eta={0.2}, gamma={0.2}
# New best param found: logloss = {0.5940708380676233}, boost_rounds = {7}
# Using CV with eta={0.3}, gamma={0.01}
# Using CV with eta={0.05}, gamma={0.01}
# Using CV with eta={0.2}, gamma={0.001}
# Using CV with eta={0.3}, gamma={5.0}
# Using CV with eta={0.05}, gamma={5.0}
# Using CV with eta={0.2}, gamma={5.0}
# New best param found: logloss = {0.5872350098289758}, boost_rounds = {8}
# Using CV with eta={0.05}, gamma={0.001}
# Using CV with subsample={0.6}, colsample_bytree={1.0}
# Using CV with subsample={0.6}, colsample_bytree={0.8}
# Using CV with subsample={1.0}, colsample_bytree={0.5}
# New best param found: logloss = {0.5867773677019854}, boost_rounds = {7}
# Using CV with subsample={1.0}, colsample_bytree={0.8}
# Using CV with subsample={1.0}, colsample_bytree={0.9}
# Using CV with subsample={1.0}, colsample_bytree={1.0}
# Using CV with max_depth={8}, min_child_weight={0}
# New best param found: logloss = {0.5843794909573422}, boost_rounds = {7}
# Using CV with max_depth={6}, min_child_weight={2}
# New best param found: logloss = {0.5717158467662669}, boost_rounds = {9}
# Using CV with max_depth={8}, min_child_weight={5}
# Using CV with max_depth={10}, min_child_weight={8}
# Using CV with max_depth={8}, min_child_weight={1}
# Using CV with max_depth={6}, min_child_weight={10}
# Using CV with max_depth={8}, min_child_weight={10}
# Using CV with max_depth={7}, min_child_weight={10}
# New best param found: logloss = {0.5709727818950265}, boost_rounds = {9}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={6}, min_child_weight={4}
# Using CV with max_depth={7}, min_child_weight={1}
# Using CV with max_depth={6}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={1}
# Using CV with max_depth={7}, min_child_weight={9}
# Using CV with max_depth={10}, min_child_weight={5}
# Using CV with max_depth={7}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={7}, min_child_weight={4}
# Using CV with max_depth={8}, min_child_weight={8}
# Using CV with eta={0.01}, gamma={2.0}
# Using CV with eta={0.3}, gamma={0}
# Using CV with eta={0.3}, gamma={0.2}
# Using CV with eta={0.05}, gamma={0}
# Using CV with eta={0.01}, gamma={0}
# Using CV with eta={0.01}, gamma={0.01}
# Using CV with eta={0.3}, gamma={0.01}
# Using CV with eta={0.01}, gamma={5.0}
# Using CV with eta={0.3}, gamma={5.0}
# Using CV with eta={0.05}, gamma={5.0}
# Using CV with eta={0.05}, gamma={3.0}
# Using CV with subsample={0.8}, colsample_bytree={1.0}
# Using CV with subsample={0.5}, colsample_bytree={1.0}
# Using CV with subsample={0.8}, colsample_bytree={0.7}
# Using CV with subsample={0.6}, colsample_bytree={0.5}
# New best param found: logloss = {0.56932436583448}, boost_rounds = {8}
# Using CV with subsample={0.6}, colsample_bytree={0.9}
# Using CV with subsample={0.8}, colsample_bytree={0.5}
# Using CV with subsample={0.5}, colsample_bytree={0.7}
# Using CV with max_depth={6}, min_child_weight={9}
# Using CV with max_depth={10}, min_child_weight={6}
# Using CV with max_depth={7}, min_child_weight={7}
# Using CV with max_depth={6}, min_child_weight={2}
# New best param found: logloss = {0.5690255567131904}, boost_rounds = {9}
# Using CV with max_depth={10}, min_child_weight={3}
# Using CV with max_depth={9}, min_child_weight={0}
# Using CV with max_depth={6}, min_child_weight={7}
# Using CV with max_depth={7}, min_child_weight={6}
# Using CV with max_depth={6}, min_child_weight={10}
# Using CV with max_depth={7}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={9}, min_child_weight={7}
# Using CV with max_depth={6}, min_child_weight={0}
# New best param found: logloss = {0.5687075193139374}, boost_rounds = {9}
# Using CV with max_depth={9}, min_child_weight={10}
# New best param found: logloss = {0.5650447565362688}, boost_rounds = {8}
# Using CV with max_depth={9}, min_child_weight={6}
# Using CV with max_depth={10}, min_child_weight={5}
# Using CV with max_depth={7}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={9}, min_child_weight={9}
# Using CV with eta={0.2}, gamma={0}
# Using CV with eta={0.01}, gamma={1.0}
# Using CV with eta={0.3}, gamma={0}
# Using CV with eta={0.3}, gamma={0.5}
# Using CV with eta={0.01}, gamma={0}
# Using CV with eta={0.01}, gamma={5.0}
# Using CV with eta={0.2}, gamma={5.0}
# Using CV with eta={0.2}, gamma={10.0}
# Using CV with eta={0.3}, gamma={0.001}
# Using CV with eta={0.3}, gamma={2.0}
# Using CV with eta={0.01}, gamma={3.0}
# Using CV with subsample={1.0}, colsample_bytree={0.7}
# Using CV with subsample={1.0}, colsample_bytree={0.9}
# Using CV with subsample={1.0}, colsample_bytree={0.5}
# Using CV with subsample={1.0}, colsample_bytree={0.6}
# Using CV with max_depth={10}, min_child_weight={8}
# Using CV with max_depth={4}, min_child_weight={10}
# Using CV with max_depth={4}, min_child_weight={7}
# Using CV with max_depth={4}, min_child_weight={9}
# Using CV with max_depth={10}, min_child_weight={4}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={8}, min_child_weight={1}
# Using CV with max_depth={8}, min_child_weight={0}
# Using CV with max_depth={8}, min_child_weight={10}
# Using CV with max_depth={4}, min_child_weight={3}
# Using CV with max_depth={8}, min_child_weight={7}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={8}, min_child_weight={5}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with max_depth={4}, min_child_weight={0}
# Using CV with eta={0.1}, gamma={1.0}
# Using CV with eta={0.2}, gamma={0}
# Using CV with eta={0.005}, gamma={0.2}
# Using CV with eta={0.1}, gamma={0}
# Using CV with eta={0.2}, gamma={0.01}
# Using CV with eta={0.1}, gamma={5.0}
# Using CV with eta={0.2}, gamma={2.0}
# Using CV with eta={0.2}, gamma={10.0}
# Using CV with eta={0.1}, gamma={0.001}
# Using CV with eta={0.005}, gamma={10.0}
# Using CV with eta={0.005}, gamma={0}
# Using CV with eta={0.005}, gamma={0.5}
# Using CV with subsample={0.8}, colsample_bytree={1.0}
# Using CV with subsample={1.0}, colsample_bytree={0.9}
# Using CV with subsample={0.8}, colsample_bytree={0.7}
# Using CV with subsample={0.7}, colsample_bytree={0.8}
# Using CV with subsample={0.7}, colsample_bytree={0.6}
# Using CV with subsample={0.7}, colsample_bytree={0.9}
# Using CV with subsample={1.0}, colsample_bytree={0.5}
# Using CV with max_depth={9}, min_child_weight={0}
# Using CV with max_depth={8}, min_child_weight={6}
# Using CV with max_depth={5}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={7}
# Using CV with max_depth={5}, min_child_weight={6}
# Using CV with max_depth={5}, min_child_weight={7}
# Using CV with max_depth={9}, min_child_weight={3}
# Using CV with max_depth={9}, min_child_weight={5}
# Using CV with max_depth={8}, min_child_weight={0}
# Using CV with max_depth={8}, min_child_weight={10}
# Using CV with max_depth={9}, min_child_weight={10}
# Using CV with max_depth={8}, min_child_weight={8}
# Using CV with max_depth={5}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={3}
# Using CV with eta={0.05}, gamma={1.0}
# Using CV with eta={0.2}, gamma={0}
# Using CV with eta={0.05}, gamma={0}
# Using CV with eta={0.05}, gamma={0.2}
# Using CV with eta={0.2}, gamma={0.5}
# Using CV with eta={0.01}, gamma={0}
# Using CV with eta={0.01}, gamma={0.2}
# Using CV with eta={0.01}, gamma={0.5}
# Using CV with eta={0.05}, gamma={0.01}
# Using CV with eta={0.2}, gamma={5.0}
# Using CV with eta={0.2}, gamma={0.001}
# Using CV with subsample={0.8}, colsample_bytree={1.0}
# Using CV with subsample={0.8}, colsample_bytree={0.7}
# Using CV with subsample={0.8}, colsample_bytree={0.6}
# Using CV with subsample={0.8}, colsample_bytree={0.8}
# Using CV with subsample={0.8}, colsample_bytree={0.5}
# Using CV with subsample={0.8}, colsample_bytree={0.9}
# Using CV with max_depth={7}, min_child_weight={0}
# Using CV with max_depth={6}, min_child_weight={8}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={7}, min_child_weight={1}
# Using CV with max_depth={10}, min_child_weight={6}
# Using CV with max_depth={6}, min_child_weight={10}
# Using CV with max_depth={6}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={4}
# Using CV with max_depth={6}, min_child_weight={2}
# Using CV with max_depth={1}, min_child_weight={9}
# Using CV with max_depth={7}, min_child_weight={10}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with max_depth={7}, min_child_weight={9}
# Using CV with eta={0.05}, gamma={1.0}
# Using CV with eta={0.05}, gamma={0}
# Using CV with eta={0.01}, gamma={1.0}
# Using CV with eta={0.05}, gamma={0.5}
# Using CV with eta={0.01}, gamma={0}
# Using CV with eta={0.01}, gamma={0.5}
# Using CV with eta={0.05}, gamma={5.0}
# Using CV with eta={0.05}, gamma={10.0}
# Using CV with eta={0.01}, gamma={0.001}
# Using CV with eta={0.05}, gamma={2.0}
# Using CV with subsample={0.8}, colsample_bytree={1.0}
# Using CV with subsample={0.6}, colsample_bytree={0.8}
# Using CV with subsample={0.9}, colsample_bytree={0.7}
# Using CV with subsample={0.6}, colsample_bytree={0.7}
# Using CV with subsample={0.9}, colsample_bytree={0.6}
# Using CV with subsample={0.8}, colsample_bytree={0.5}
# Using CV with subsample={0.8}, colsample_bytree={0.8}
# Using CV with max_depth={10}, min_child_weight={8}
# Using CV with max_depth={9}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={3}
# Using CV with max_depth={5}, min_child_weight={10}
# Using CV with max_depth={9}, min_child_weight={1}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={5}, min_child_weight={8}
# Using CV with max_depth={5}, min_child_weight={7}
# Using CV with max_depth={9}, min_child_weight={10}
# Using CV with max_depth={1}, min_child_weight={6}
# Using CV with max_depth={5}, min_child_weight={0}
# Using CV with max_depth={9}, min_child_weight={6}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={3}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with max_depth={5}, min_child_weight={3}
# Using CV with eta={0.05}, gamma={0}
# Using CV with eta={0.05}, gamma={0.5}
# Using CV with eta={0.2}, gamma={0}
# Using CV with eta={0.2}, gamma={3.0}
# Using CV with eta={0.05}, gamma={0.01}
# Using CV with eta={0.2}, gamma={0.01}
# Using CV with eta={0.05}, gamma={10.0}
# Using CV with eta={0.2}, gamma={0.001}
# Using CV with eta={0.05}, gamma={3.0}
# Using CV with subsample={0.7}, colsample_bytree={0.6}
# Using CV with subsample={0.7}, colsample_bytree={0.5}
# Using CV with subsample={0.7}, colsample_bytree={0.7}
# Using CV with subsample={1.0}, colsample_bytree={0.5}
# Using CV with subsample={1.0}, colsample_bytree={0.6}
# Using CV with subsample={1.0}, colsample_bytree={0.9}
# Using CV with max_depth={6}, min_child_weight={9}
# Using CV with max_depth={3}, min_child_weight={0}
# Using CV with max_depth={2}, min_child_weight={8}
# Using CV with max_depth={10}, min_child_weight={6}
# Using CV with max_depth={2}, min_child_weight={5}
# Using CV with max_depth={10}, min_child_weight={3}
# Using CV with max_depth={3}, min_child_weight={10}
# Using CV with max_depth={6}, min_child_weight={10}
# Using CV with max_depth={6}, min_child_weight={3}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={3}, min_child_weight={2}
# Using CV with max_depth={6}, min_child_weight={0}
# Using CV with max_depth={2}, min_child_weight={10}
# Using CV with max_depth={3}, min_child_weight={9}
# Using CV with max_depth={10}, min_child_weight={1}
# Using CV with max_depth={6}, min_child_weight={8}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={2}, min_child_weight={0}
# Using CV with max_depth={3}, min_child_weight={4}
# Using CV with eta={0.005}, gamma={3.0}
# Using CV with eta={0.3}, gamma={1.0}
# Using CV with eta={0.3}, gamma={0}
# Using CV with eta={0.01}, gamma={1.0}
# Using CV with eta={0.01}, gamma={0}
# Using CV with eta={0.01}, gamma={10.0}
# Using CV with eta={0.3}, gamma={3.0}
# Using CV with eta={0.005}, gamma={10.0}
# Using CV with eta={0.005}, gamma={0}
# Using CV with eta={0.01}, gamma={3.0}

# %%
best_param
# Out:
# {'max_depth': 9,
#  'eta': 0.2,
#  'min_child_weight': 10,
#  'verbosity': 0,
#  'objective': 'binary:logistic',
#  'silent': 'True',
#  'gamma': 5.0,
#  'subsample': 0.6,
#  'colsample_bytree': 0.5,
#  'eval_metric': 'logloss'}

# %%
*** only use PEG (try to find 100nm)
*** maybe look at different features (poor distributions)
        heterogenious in different ways
        different features are responsible to accuracies
*** think about to present code/results!
# Out:
#   File "<ipython-input-29-b85bd77dfa8e>", line 1
#     *** only use PEG (try to find 100nm)
#      ^
# SyntaxError: invalid syntax

# %%
evals = [(dtrain, 'train'), (dval, 'eval')]
num_round = best_boost_rounds
bst = xgb.train(best_param, dtrain, num_round, evals, early_stopping_rounds=3, )


######
label = dtest.get_label()
ypred1 = bst.predict(dtest)
# by default, we predict using all the trees
alpha = 0.47
pred = [0 if i < alpha else 1 for i in ypred1]
print("Accuracy:",metrics.accuracy_score(y_test, pred))
# Out:
# [0]	train-logloss:0.596848	eval-logloss:0.650535
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 3 rounds.
# [1]	train-logloss:0.537726	eval-logloss:0.627915
# [2]	train-logloss:0.486548	eval-logloss:0.608327
# [3]	train-logloss:0.451693	eval-logloss:0.598672
# [4]	train-logloss:0.419371	eval-logloss:0.589023
# [5]	train-logloss:0.387183	eval-logloss:0.580524
# [6]	train-logloss:0.359427	eval-logloss:0.579489
# [7]	train-logloss:0.343741	eval-logloss:0.577812
# Accuracy: 0.6960686204431737

# %%
from datetime import date
import json
bst.save_model(f'model_xgboost_P21_P32_{str(date.today())}')
with open(f'config_xgboost_P21_P32_{str(date.today())}', 'w', encoding='utf-8') as f:
    json.dump(bst.save_config(), f, ensure_ascii=False, indent=4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-5328d1264b30> in <module>
#       3 bst.save_model(f'model_xgboost_P21_P32_{str(date.today())}')
#       4 with open(f'config_xgboost_P21_P32_{str(date.today())}', 'w', encoding='utf-8') as f:
# ----> 5     json.dump(bst.save_config(), f, ensure_ascii=False, indent=4)
#
# AttributeError: 'Booster' object has no attribute 'save_config'

# %%
bst.load_model(f'model_xgboost_P21_P32_2020-07-19')
with open(f'config_xgboost_P21_P32_2020-07-19', 'r', encoding='utf-8') as f:
    config = json.load(f)
bst.load_config(config)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-38-9ae658e9f317> in <module>
# ----> 1 bst.load_model(f'model_xgboost_P21_P32_2020-07-19')
#       2 with open(f'config_xgboost_P21_P32_2020-07-19', 'r', encoding='utf-8') as f:
#       3     config = json.load(f)
#       4 bst.load_config(config)
#
# /opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py in load_model(self, fname)
#
# /opt/anaconda3/lib/python3.7/site-packages/xgboost/core.py in _check_call(ret)
#
# XGBoostError: [17:57:13] src/io/local_filesys.cc:209: Check failed: allow_null:  LocalFileSystem::Open "model_xgboost_P21_P32_2020-07-19": No such file or directory
# Stack trace:
#   [bt] (0) 1   libxgboost.dylib                    0x0000001a1c1fbe89 dmlc::LogMessageFatal::~LogMessageFatal() + 57
#   [bt] (1) 2   libxgboost.dylib                    0x0000001a1c2ea65d dmlc::io::LocalFileSystem::Open(dmlc::io::URI const&, char const*, bool) + 989
#   [bt] (2) 3   libxgboost.dylib                    0x0000001a1c2e184c dmlc::Stream::Create(char const*, char const*, bool) + 76
#   [bt] (3) 4   libxgboost.dylib                    0x0000001a1c217286 XGBoosterLoadModel + 118
#   [bt] (4) 5   libffi.7.dylib                      0x0000000109ec3ead ffi_call_unix64 + 85
#   [bt] (5) 6   ???                                 0x00007ffee68c8da0 0x0 + 140732766391712

# %%
alpha = 0.47
ypred1 = bst.predict(dtest)
# by default, we predict using all the trees
pred = [0 if i < alpha else 1 for i in ypred1]

print("Accuracy:",metrics.accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.6960686204431737

# %%
# Fix for using xgboost model with SHAP. 
# Will remove first 4 characters of the raw 
# file which was causing issues
model_bytearray = bst.save_raw()[4:]
def myfun(self=None):
    return model_bytearray
bst.save_raw = myfun

# %%
# import ctypes

# def c_array(ctype, values):
#     """Convert a python string to c array."""
#     if (isinstance(values, np.ndarray)
#             and values.dtype.itemsize == ctypes.sizeof(ctype)):
#         return (ctype * len(values)).from_buffer_copy(values)
#     return (ctype * len(values))(*values)

# mats = c_array(ctypes.c_void_p, [dtrain.handle])

# %%
# tst = X_test[features + [target]]
# tst['tst'] = y_test
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
results = X_test[features]
results['predicted'] = pred
results['actual'] = y_test

# %% [markdown]
# ## 4.   Evaluate Results

# %%
# print('0 == {}'.format(le.inverse_transform([0])))
# print('1 == {}'.format(le.inverse_transform([1])))
# print('2 == {}'.format(le.inverse_transform([2])))
# print('3 == {}'.format(le.inverse_transform([3])))
class_names = ['P21', 'P35']
class_results = classification_report(y_test, pred, digits=4, target_names = ['P21', 'P35'])
print(str(class_results))
# Out:
#               precision    recall  f1-score   support
#
#          P21     0.7200    0.6528    0.6848      3537
#          P35     0.6758    0.7403    0.7066      3458
#
#     accuracy                         0.6961      6995
#    macro avg     0.6979    0.6966    0.6957      6995
# weighted avg     0.6982    0.6961    0.6956      6995

# %%
confusion_matrix(y_test, pred)
pl.figure(figsize=(12,10))
cm_array = confusion_matrix(y_test, pred)
df_cm = pd.DataFrame(cm_array, index = class_names, columns = class_names)

sn.set(font_scale=1.4) # for label size
ax = sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, cmap="YlGnBu")
ax.set(xlabel='Actual', ylabel='Predicted')

pl.show()

# %%
explainer = shap.TreeExplainer(bst)
shap_values = explainer.shap_values(X_test[features])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-44-871ed0527ab2> in <module>
# ----> 1 explainer = shap.TreeExplainer(bst)
#       2 shap_values = explainer.shap_values(X_test[features])
#
# /opt/anaconda3/lib/python3.7/site-packages/shap/explainers/_tree.py in __init__(self, model, data, model_output, feature_perturbation, **deprecated_options)
#     134         self.feature_perturbation = feature_perturbation
#     135         self.expected_value = None
# --> 136         self.model = TreeEnsemble(model, self.data, self.data_missing, model_output)
#     137         self.model_output = model_output
#     138         #self.model_output = self.model.model_output # this allows the TreeEnsemble to translate model outputs types by how it loads the model
#
# /opt/anaconda3/lib/python3.7/site-packages/shap/explainers/_tree.py in __init__(self, model, data, data_missing, model_output)
#     778             self.original_model = model
#     779             self.model_type = "xgboost"
# --> 780             xgb_loader = XGBTreeModelLoader(self.original_model)
#     781             self.trees = xgb_loader.get_trees(data=data, data_missing=data_missing)
#     782             self.base_offset = xgb_loader.base_score
#
# /opt/anaconda3/lib/python3.7/site-packages/shap/explainers/_tree.py in __init__(self, xgb_model)
#    1393         self.read_arr('i', 29) # reserved
#    1394         self.name_obj_len = self.read('Q')
# -> 1395         self.name_obj = self.read_str(self.name_obj_len)
#    1396         self.name_gbm_len = self.read('Q')
#    1397         self.name_gbm = self.read_str(self.name_gbm_len)
#
# /opt/anaconda3/lib/python3.7/site-packages/shap/explainers/_tree.py in read_str(self, size)
#    1513
#    1514     def read_str(self, size):
# -> 1515         val = self.buf[self.pos:self.pos+size].decode('utf-8')
#    1516         self.pos += size
#    1517         return val
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf9 in position 189: invalid start byte

# %%
# %matplotlib inline

# %%
class_inds
# Out:
# array([0], dtype=int64)

# %%
colors = ['#999999', '#e5bf62', '#7995e9', '#a64ca6']
class_inds = np.argsort([-np.abs(shap_values[i]).mean() for i in range(len(shap_values))])
cmap = plt_colors.ListedColormap(np.array(colors)[class_inds])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-d916a6fd5aa0> in <module>
#       1 colors = ['#999999', '#e5bf62', '#7995e9', '#a64ca6']
# ----> 2 class_inds = np.argsort([-np.abs(shap_values[i]).mean() for i in range(len(shap_values))])
#       3 cmap = plt_colors.ListedColormap(np.array(colors)[class_inds])
#
# NameError: name 'shap_values' is not defined

# %%
# sn.reset_orig() # Reset matplot lib to no longer use seaborn

# %%
shap.summary_plot(shap_values, X_test[features], class_names=np.array(class_names), title='Total SHAP Values', plot_type='bar', color='#e5bf62')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-7459440f7782> in <module>
# ----> 1 shap.summary_plot(shap_values, X_test[features], class_names=np.array(class_names), title='Total SHAP Values', plot_type='bar', color='#e5bf62')
#
# NameError: name 'shap_values' is not defined

# %%
test = enumerate(['#999999'])

# %%
#------SHAP-FILE--------------
import random

def get_cmap(shap_values):
    class_inds = np.argsort([-np.abs(shap_values[i]).mean() for i in range(len(shap_values))])
    cmap = plt_colors.ListedColormap(np.array(colors)[class_inds])
    return cmap

def plot_dependency(feature_name, shap_values, X_df, fig_dim, color, figsize=None, y_range=None, alpha=None):
    if len(list(color)) is not 1:
        color = get_cmap(shap_values)
    colors = enumerate(color)
    fig, axs = pl.subplots(*fig_dim, figsize=figsize)
#     ax = axs.ravel()
    cnt = 0
    if (fig_dim == (1, 1)):
        if figsize is not None:
            axs[x][y].set_ylim(*figsize)
        shap.dependence_plot(feature_name, shap_values, X_df, interaction_index=None, color=next(colors)[1], ax=axs)
    else:
        for x in range(fig_dim[0]):
            for y in range(fig_dim[1]):
                if figsize is not None:
                    axs[x][y].set_ylim(*figsize)
                shap.dependence_plot(feature_name, shap_values, X_df, interaction_index=None, color=next(colors)[1], ax=axs[x][y])
                cnt+=1

plot_dependency("Mean Deff1", shap_values, X_test[features], (1,1), ['#e5bf62'])

# %%
pl.ioff()
# %matplotlib inline

figsize = (7.5, 5)
bottom = -2.0
top = 2.0
for i in range(len(shap_values)):
    fig = pl.figure(figsize=figsize)
    ax = fig.gca()
    ax.set_ylim(bottom, top)
    shap.dependence_plot("Mean Deff1", shap_values[i], X_test[features], interaction_index = None, color=colors[i], alpha=0.5, ax=ax)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-313-b9ce31f8121c> in <module>
#      10     ax.set_ylim(bottom, top)
#      11
# ---> 12     shap.dependence_plot("Mean Deff1", np.reshape(shap_values[i], [len(shap_values[i]), 1], 'C'), X_test[features], interaction_index = None, color=colors[i], alpha=0.5, ax=ax)
#
# C:\ProgramData\Miniconda3\lib\site-packages\shap\plots\dependence.py in dependence_plot(ind, shap_values, features, feature_names, display_features, interaction_index, color, axis_color, cmap, dot_size, x_jitter, alpha, title, xmin, xmax, ax, show)
#     147
#     148     assert shap_values.shape[0] == features.shape[0], \
# --> 149         "'shap_values' and 'features' values must have the same number of rows!"
#     150     assert shap_values.shape[1] == features.shape[1], \
#     151         "'shap_values' must have the same number of columns as 'features'!"
#
# AssertionError: 'shap_values' and 'features' values must have the same number of rows!

# %%
np.reshape(shap_values[i], [1, len(shap_values[i])], 'C').shape
# Out:
# (1, 39)

# %%
len(features)
# Out:
# 39

# %%
np.reshape(shap_values[i], [1, len(shap_values[i])], 'C')
# Out:
# array([[ 1.46145304e-03, -9.12541989e-03,  1.39519077e-04,
#         -7.88226782e-04, -4.04666318e-03, -1.71901665e-05,
#         -1.97810325e-04,  2.35524931e-05, -3.58266220e-03,
#         -4.26636077e-04, -8.16290922e-05,  3.53004812e-04,
#         -4.37474868e-04,  1.84119664e-04, -1.10024284e-03,
#         -5.80706773e-03,  9.25729037e-05, -3.28503986e-04,
#          5.99268964e-03, -1.58801861e-03, -4.15220717e-03,
#          1.32650612e-02, -4.70045768e-03,  5.66091314e-02,
#         -1.17288858e-01,  1.01887621e-01,  5.08539891e-03,
#          1.25179775e-02, -2.58221477e-02,  6.80549210e-03,
#          2.66569853e-03,  8.47028941e-02,  3.61474127e-01,
#          4.62763160e-02,  5.05841859e-02,  1.39438868e-01,
#         -8.90849531e-02, -1.50520936e-01, -1.40766725e-01]], dtype=float32)

# %%
figsize = (7.5, 5)
bottom = -1.2
top = 1.2
for i in range(len(shap_values)):
    fig = pl.figure(figsize=figsize)
    ax = fig.gca()
    ax.set_ylim(bottom, top)
    shap.dependence_plot("Mean fractal_dim", shap_values[i], X_test[features], interaction_index = None, color=colors[i], alpha=0.5, ax=ax)

# %%
figsize = (7.5, 5)
bottom = -1.5
top = 1.5
for i in range(len(shap_values)):
    fig = pl.figure(figsize=figsize)
    ax = fig.gca()
    ax.set_ylim(bottom, top)
    shap.dependence_plot("Mean D_fit", shap_values[i], X_test[features], interaction_index = None, color=colors[i], alpha=0.5, ax=ax)

# %%
figsize = (7.5, 5)
bottom = -1.0
top = 1.0
for i in range(len(shap_values)):
    fig = pl.figure(figsize=figsize)
    ax = fig.gca()
    ax.set_ylim(bottom, top)
    shap.dependence_plot("Mean MSD_ratio", shap_values[i], X_test[features], interaction_index = None, color=colors[i], alpha=0.5, ax=ax)

# %%
shap.summary_plot(shap_values[0], X_test[features], max_display=5, class_names = class_names, title = 'SHAP Value for P14')

# %%
shap.summary_plot(shap_values[1], X_test[features], max_display=5, class_names = class_names, title = 'SHAP Value for P21')

# %%
shap.summary_plot(shap_values[2], X_test[features], max_display=5, class_names = class_names, title='SHAP Value for P28')

# %%
shap.summary_plot(shap_values[3], X_test[features], max_display=5, class_names=class_names, title='SHAP Value for P35')

# %%
from modules import anim_plot_changed
from importlib import reload
reload(anim_plot_changed)

_ = anim_plot_changed.rotate_3d(results, [top_feat[0], top_feat[1], top_feat[2]])
_ = anim_plot_changed.rotate_3d(results, [top_feat[0], top_feat[2], top_feat[3]])
_ = anim_plot_changed.rotate_3d(results, [top_feat[1], top_feat[2], top_feat[3]])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-290-f9b4c73f435f> in <module>
# ----> 1 from modules import anim_plot_changed
#       2 from importlib import reload
#       3 reload(anim_plot_changed)
#       4
#       5 _ = anim_plot_changed.rotate_3d(results, [top_feat[0], top_feat[1], top_feat[2]])
#
# ImportError: cannot import name 'anim_plot_changed' from 'modules' (unknown location)

# %%
from modules import anim_plot_changed
from importlib import reload
reload(anim_plot_changed)

_ = anim_plot_changed.rotate_3d(results, [top_feat[0], top_feat[1], top_feat[2]], anim_param={'frames':np.arange(0,720,1)}, save_param={'filename':'This_is_a_test.gif','fps':50})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-281-1b2d347e7149> in <module>
# ----> 1 from modules import anim_plot_changed
#       2 from importlib import reload
#       3 reload(anim_plot_changed)
#       4
#       5 _ = anim_plot_changed.rotate_3d(results, [top_feat[0], top_feat[1], top_feat[2]], anim_param={'frames':np.arange(0,720,1)}, save_param={'filename':'This_is_a_test.gif','fps':50})
#
# ImportError: cannot import name 'anim_plot_changed' from 'modules' (unknown location)

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
print(model.feature_importances_)
# Out:
# [0.00962911 0.0130419  0.01032248 0.00799298 0.         0.
#  0.00863212 0.         0.00949946 0.00976907 0.         0.00840124
#  0.00986694 0.0089294  0.01388821 0.01285382 0.00772611 0.00840508
#  0.01152527 0.01121536 0.01360808 0.02683435 0.0153235  0.03825277
#  0.04791635 0.03967494 0.03504856 0.04391031 0.03684536 0.04382398
#  0.03634356 0.0360228  0.05182744 0.05954881 0.03185003 0.03756746
#  0.04233065 0.1269696  0.07460289]

# %%
# Feature search (new) -------not in file--------: 
import operator
from sklearn.metrics import accuracy_score

def feature_thresholding_helper(X_train, X_test, X_val, new_feat):
    dtrain = xgb.DMatrix(X_train[new_feat], label=y_train)
    dtest = xgb.DMatrix(X_test[new_feat], label=y_test)
    dval = xgb.DMatrix(X_val[new_feat], label=y_val)
    return dtrain, dtest, dval

def feature_thresholding(X_train, y_train, X_test, y_test, X_val, y_val, params, features, nfold=5, num_boost_round=2000, early_stopping_rounds=3, metrics={'mlogloss', 'merror'}, thresh=np.arange(0,.1,.002)):
    best_thresh = -1
    if params['eval_metric'] in ['map', 'auc', 'aucpr']:
        best_eval = -np.inf
        eval_f = operator.gt
    else: 
        best_eval = np.inf
        eval_f = operator.lt
    
    best_eval = -np.inf
    eval_f = operator.gt
    
    for t in thresh:
        print(f"Using thresh = {t} ",end = '| ')
        new_feat = list(np.array(features)[np.array(model.feature_importances_ > t)])

#         cv_model = cv(params, 
#                       X_train, 
#                       y_train, 
#                       features=new_feat, 
#                       nfold=nfold, 
#                       num_boost_round=num_boost_round, 
#                       early_stopping_rounds=early_stopping_rounds, 
#                       metrics=metrics) 
#         cv_eval = cv_model[f"test-{'merror'}-mean"].min()
#         print(f"Eval = {cv_eval} ", end = '| ')
#         if eval_f(cv_eval, best_eval):
#             best_thresh = t
#             best_eval = cv_eval

        dtrain, dtest, dval = feature_thresholding_helper(X_train, X_test, X_val, new_feat)
        evals = [(dtrain, 'train'), (dval, 'eval')]
        bst2 = xgb.train(best_param, dtrain, 1500, evals, early_stopping_rounds=3, verbose_eval=False)
        ######
        label = dtest.get_label()
        ypred1 = bst2.predict(dtest)
        # by default, we predict using all the trees
        pred2 = [np.where(x == np.max(x))[0][0] for x in ypred1]

        cv_eval = accuracy_score(y_test, pred2)
        if eval_f(cv_eval, best_eval):
            best_thresh = t
            best_eval = cv_eval
            
        print(f"Best eval = {best_eval}, Best threshold = {best_thresh}")
    print(f"Features used:\n{np.array(features)[np.array(model.feature_importances_ > best_thresh)]}")
    return list(np.array(features)[np.array(model.feature_importances_ > best_thresh)])

new_feat = feature_thresholding(X_train, y_train, X_test, y_test, X_val, y_val, best_param, features)
# Out:
# Using thresh = 0.0 | Best eval = 0.4993160054719562, Best threshold = 0.0
# Using thresh = 0.002 | Best eval = 0.4993160054719562, Best threshold = 0.0
# Using thresh = 0.004 | Best eval = 0.4993160054719562, Best threshold = 0.0
# Using thresh = 0.006 | Best eval = 0.4993160054719562, Best threshold = 0.0
# Using thresh = 0.008 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.01 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.012 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.014 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.016 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.018000000000000002 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.02 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.022 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.024 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.026000000000000002 | Best eval = 0.5036935704514364, Best threshold = 0.008
# Using thresh = 0.028 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.03 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.032 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.034 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.036000000000000004 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.038 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.04 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.042 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.044 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.046 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.048 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.05 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.052000000000000005 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.054 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.056 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.058 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.06 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.062 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.064 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.066 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.068 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.07 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.07200000000000001 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.074 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.076 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.078 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.08 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.082 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.084 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.08600000000000001 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.088 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.09 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.092 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.094 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.096 | Best eval = 0.504514363885089, Best threshold = 0.028
# Using thresh = 0.098 | Best eval = 0.504514363885089, Best threshold = 0.028
# Features used:
# ['Mean alpha' 'Mean D_fit' 'Mean kurtosis' 'Mean asymmetry1'
#  'Mean asymmetry2' 'Mean asymmetry3' 'Mean AR' 'Mean elongation'
#  'Mean boundedness' 'Mean fractal_dim' 'Mean trappedness'
#  'Mean efficiency' 'Mean straightness' 'Mean MSD_ratio' 'Mean Deff1'
#  'Mean Deff2']

# %%
new_feat = list(np.array(features)[np.array(model.feature_importances_ > best_thresh)])

# %%
cv_model = cv(best_param, 
              X_train, 
              y_train, 
              features=new_feat, 
              nfold=5, 
              num_boost_round=best_boost_rounds, 
              early_stopping_rounds=3, 
              metrics={'mlogloss', 'merror'}) 
cv_model

# %%
dtrain = xgb.DMatrix(X_train[new_feat], label=y_train)
dtest = xgb.DMatrix(X_test[new_feat], label=y_test)
dval = xgb.DMatrix(X_val[new_feat], label=y_val)

# %%
evals = [(dtrain, 'train'), (dval, 'eval')]
num_round = best_boost_rounds
bst = xgb.train(best_param, dtrain, num_round, evals, early_stopping_rounds=3, )


######
label = dtest.get_label()
ypred1 = bst.predict(dtest)
# by default, we predict using all the trees
pred = [np.where(x == np.max(x))[0][0] for x in ypred1]
# Out:
# [0]	train-mlogloss:1.38480	eval-mlogloss:1.38538
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# Will train until eval-mlogloss hasn't improved in 3 rounds.
# [1]	train-mlogloss:1.38298	eval-mlogloss:1.38424
# [2]	train-mlogloss:1.38080	eval-mlogloss:1.38266
# [3]	train-mlogloss:1.37877	eval-mlogloss:1.38131
# [4]	train-mlogloss:1.37662	eval-mlogloss:1.37985
# [5]	train-mlogloss:1.37462	eval-mlogloss:1.37853
# [6]	train-mlogloss:1.37239	eval-mlogloss:1.37699
# [7]	train-mlogloss:1.37065	eval-mlogloss:1.37585
# [8]	train-mlogloss:1.36888	eval-mlogloss:1.37481
# [438]	train-mlogloss:0.97296	eval-mlogloss:1.15463
# [439]	train-mlogloss:0.97246	eval-mlogloss:1.15442
# [440]	train-mlogloss:0.97200	eval-mlogloss:1.15426
# [441]	train-mlogloss:0.97160	eval-mlogloss:1.15410
# [442]	train-mlogloss:0.97117	eval-mlogloss:1.15396
# [443]	train-mlogloss:0.97073	eval-mlogloss:1.15386
# [444]	train-mlogloss:0.97029	eval-mlogloss:1.15372
# [445]	train-mlogloss:0.96990	eval-mlogloss:1.15353
# [446]	train-mlogloss:0.96942	eval-mlogloss:1.15331
# [447]	train-mlogloss:0.96893	eval-mlogloss:1.15312
# [448]	train-mlogloss:0.96846	eval-mlogloss:1.15297
# [449]	train-mlogloss:0.96803	eval-mlogloss:1.15281
# [450]	train-mlogloss:0.96764	eval-mlogloss:1.15267
# [451]	train-mlogloss:0.96725	eval-mlogloss:1.15251
# [452]	train-mlogloss:0.96687	eval-mlogloss:1.15235
# [453]	train-mlogloss:0.96649	eval-mlogloss:1.15220
# [454]	train-mlogloss:0.96613	eval-mlogloss:1.15212
# [455]	train-mlogloss:0.96564	eval-mlogloss:1.15200
# [456]	train-mlogloss:0.96524	eval-mlogloss:1.15187
# [457]	train-mlogloss:0.96485	eval-mlogloss:1.15176
# [458]	train-mlogloss:0.96445	eval-mlogloss:1.15166
# [459]	train-mlogloss:0.96406	eval-mlogloss:1.15154
# [460]	train-mlogloss:0.96360	eval-mlogloss:1.15138
# [461]	train-mlogloss:0.96320	eval-mlogloss:1.15131
# [462]	train-mlogloss:0.96278	eval-mlogloss:1.15115
# [463]	train-mlogloss:0.96245	eval-mlogloss:1.15108
# [464]	train-mlogloss:0.96200	eval-mlogloss:1.15094
# [465]	train-mlogloss:0.96162	eval-mlogloss:1.15082
# [466]	train-mlogloss:0.96125	eval-mlogloss:1.15075
# [467]	train-mlogloss:0.96085	eval-mlogloss:1.15063
# [468]	train-mlogloss:0.96045	eval-mlogloss:1.15051
# [469]	train-mlogloss:0.96000	eval-mlogloss:1.15042
# [470]	train-mlogloss:0.95963	eval-mlogloss:1.15037
# [471]	train-mlogloss:0.95919	eval-mlogloss:1.15029
# [472]	train-mlogloss:0.95885	eval-mlogloss:1.15012
# [473]	train-mlogloss:0.95846	eval-mlogloss:1.14994
# [474]	train-mlogloss:0.95800	eval-mlogloss:1.14976
# [475]	train-mlogloss:0.95754	eval-mlogloss:1.14967
# [476]	train-mlogloss:0.95715	eval-mlogloss:1.14952
# [477]	train-mlogloss:0.95673	eval-mlogloss:1.14944
# [478]	train-mlogloss:0.95633	eval-mlogloss:1.14934
# [479]	train-mlogloss:0.95592	eval-mlogloss:1.14916
# [480]	train-mlogloss:0.95555	eval-mlogloss:1.14904
# [481]	train-mlogloss:0.95512	eval-mlogloss:1.14889
# [482]	train-mlogloss:0.95478	eval-mlogloss:1.14879
# [483]	train-mlogloss:0.95443	eval-mlogloss:1.14865
# [484]	train-mlogloss:0.95396	eval-mlogloss:1.14853
# [485]	train-mlogloss:0.95364	eval-mlogloss:1.14845
# [724]	train-mlogloss:0.88134	eval-mlogloss:1.13234
# [725]	train-mlogloss:0.88113	eval-mlogloss:1.13228
# [726]	train-mlogloss:0.88096	eval-mlogloss:1.13230
# [727]	train-mlogloss:0.88073	eval-mlogloss:1.13230
# [728]	train-mlogloss:0.88051	eval-mlogloss:1.13231
# Stopping. Best iteration:
# [725]	train-mlogloss:0.88113	eval-mlogloss:1.13228

# %%
# print('0 == {}'.format(le.inverse_transform([0])))
# print('1 == {}'.format(le.inverse_transform([1])))
# print('2 == {}'.format(le.inverse_transform([2])))
# print('3 == {}'.format(le.inverse_transform([3])))
class_names = ['P14', 'P21', 'P28', 'P35']
class_results = classification_report(y_test, pred, digits=4, target_names = ['P14', 'P21', 'P28', 'P35'])
print(str(class_results))
# Out:
#               precision    recall  f1-score   support
#
#          P14     0.6306    0.7071    0.6667       898
#          P21     0.4256    0.5091    0.4636       876
#          P28     0.3953    0.2662    0.3181       943
#          P35     0.5202    0.5352    0.5276       938
#
#     accuracy                         0.5018      3655
#    macro avg     0.4929    0.5044    0.4940      3655
# weighted avg     0.4924    0.5018    0.4924      3655

# %%
# Running CV with newly thresholded features; using new seed of 123 to get different unique GS hyperparams
best_model2, best_param2, best_eval2, best_boost_rounds2 = xgb_paramsearch(X_train, y_train, new_feat, init_params=best_param, nfold=5, num_boost_round=2000, early_stopping_rounds=3, metrics={'mlogloss', 'merror'}, use_gpu='True', seed=123)
# Out:
# Using CV with subsample={0.7}, colsample_bytree={0.7}
# New best param found: mlogloss = {1.05563476842045}, boost_rounds = {1116}
# Using CV with subsample={0.7}, colsample_bytree={0.8}
# Using CV with subsample={0.7}, colsample_bytree={0.6}
# Using CV with subsample={0.9}, colsample_bytree={0.6}
# Using CV with subsample={0.9}, colsample_bytree={0.5}
# Using CV with subsample={1.0}, colsample_bytree={0.8}
# Using CV with subsample={1.0}, colsample_bytree={0.7}
# Using CV with subsample={1.0}, colsample_bytree={0.6}
# Using CV with max_depth={1}, min_child_weight={2}
# Using CV with max_depth={4}, min_child_weight={10}
# Using CV with max_depth={4}, min_child_weight={7}
# Using CV with max_depth={1}, min_child_weight={3}
# Using CV with max_depth={10}, min_child_weight={4}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={4}, min_child_weight={4}
# Using CV with max_depth={1}, min_child_weight={4}
# Using CV with max_depth={1}, min_child_weight={7}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={4}, min_child_weight={2}
# Using CV with max_depth={1}, min_child_weight={1}
# Using CV with max_depth={4}, min_child_weight={0}
# Using CV with eta={0.005}, gamma={3.0}
# Using CV with eta={0.3}, gamma={2.0}
# Using CV with eta={0.3}, gamma={0}
# Using CV with eta={0.005}, gamma={0.2}
# Using CV with eta={0.005}, gamma={0.001}
# Using CV with eta={0.005}, gamma={5.0}
# Using CV with eta={0.3}, gamma={3.0}
# Using CV with eta={0.3}, gamma={0.001}
# Using CV with eta={0.005}, gamma={1.0}
# Using CV with eta={0.005}, gamma={0}
# Using CV with eta={0.005}, gamma={0.5}
# Using CV with subsample={0.6}, colsample_bytree={1.0}
# Using CV with subsample={0.7}, colsample_bytree={1.0}
# Using CV with subsample={0.9}, colsample_bytree={0.6}
# Using CV with subsample={0.9}, colsample_bytree={0.9}
# Using CV with subsample={0.9}, colsample_bytree={0.5}
# Using CV with subsample={0.6}, colsample_bytree={0.9}
# Using CV with subsample={0.7}, colsample_bytree={0.9}
# Using CV with subsample={0.7}, colsample_bytree={0.8}
# Using CV with max_depth={9}, min_child_weight={0}
# Using CV with max_depth={7}, min_child_weight={0}
# Using CV with max_depth={9}, min_child_weight={1}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={7}, min_child_weight={1}
# Using CV with max_depth={9}, min_child_weight={9}
# Using CV with max_depth={9}, min_child_weight={10}
# Using CV with max_depth={1}, min_child_weight={9}
# Using CV with max_depth={7}, min_child_weight={10}
# New best param found: mlogloss = {1.0555034434075687}, boost_rounds = {1116}
# Using CV with max_depth={9}, min_child_weight={4}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={7}, min_child_weight={2}
# Using CV with max_depth={1}, min_child_weight={1}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with eta={0.3}, gamma={1.0}
# Using CV with eta={0.3}, gamma={0}
# Using CV with eta={0.1}, gamma={0}
# Using CV with eta={0.005}, gamma={0.2}
# Using CV with eta={0.005}, gamma={2.0}
# Using CV with eta={0.3}, gamma={0.01}
# Using CV with eta={0.1}, gamma={5.0}
# Using CV with eta={0.3}, gamma={10.0}
# Using CV with eta={0.005}, gamma={0.5}
# Using CV with eta={0.1}, gamma={2.0}
# Using CV with eta={0.005}, gamma={0}
# Using CV with subsample={0.7}, colsample_bytree={1.0}
# Using CV with subsample={0.7}, colsample_bytree={0.7}
# Using CV with subsample={0.7}, colsample_bytree={0.8}
# Using CV with subsample={1.0}, colsample_bytree={0.5}
# Using CV with subsample={1.0}, colsample_bytree={0.8}
# Using CV with subsample={1.0}, colsample_bytree={0.9}
# Using CV with subsample={1.0}, colsample_bytree={1.0}
# Using CV with max_depth={5}, min_child_weight={9}
# Using CV with max_depth={1}, min_child_weight={3}
# Using CV with max_depth={6}, min_child_weight={7}
# New best param found: mlogloss = {1.0553094309841415}, boost_rounds = {1143}
# Using CV with max_depth={5}, min_child_weight={10}
# Using CV with max_depth={5}, min_child_weight={5}
# New best param found: mlogloss = {1.0552115049521955}, boost_rounds = {1169}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={6}, min_child_weight={10}
# Using CV with max_depth={5}, min_child_weight={7}
# Using CV with max_depth={6}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={5}
# Using CV with max_depth={6}, min_child_weight={2}
# Using CV with max_depth={1}, min_child_weight={9}
# Using CV with max_depth={5}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with max_depth={10}, min_child_weight={2}
# Using CV with eta={0.2}, gamma={1.0}
# Using CV with eta={0.2}, gamma={0}
# Using CV with eta={0.01}, gamma={1.0}
# Using CV with eta={0.01}, gamma={0.5}
# Using CV with eta={0.01}, gamma={0}
# Using CV with eta={0.01}, gamma={5.0}
# Using CV with eta={0.2}, gamma={5.0}
# Using CV with eta={0.01}, gamma={0.001}
# Using CV with eta={0.2}, gamma={3.0}
# Using CV with eta={0.01}, gamma={3.0}
# Using CV with subsample={0.7}, colsample_bytree={1.0}
# Using CV with subsample={0.7}, colsample_bytree={0.5}
# Using CV with subsample={0.6}, colsample_bytree={0.6}
# New best param found: mlogloss = {1.0548073140779755}, boost_rounds = {1220}
# Using CV with subsample={0.7}, colsample_bytree={0.9}
# Using CV with subsample={0.6}, colsample_bytree={0.5}
# Using CV with subsample={0.8}, colsample_bytree={0.7}
# Using CV with subsample={0.8}, colsample_bytree={0.8}
# Using CV with max_depth={7}, min_child_weight={3}
# New best param found: mlogloss = {1.0541575875651228}, boost_rounds = {1220}
# Using CV with max_depth={7}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={10}
# New best param found: mlogloss = {1.053628974237133}, boost_rounds = {1222}
# Using CV with max_depth={7}, min_child_weight={6}
# Using CV with max_depth={10}, min_child_weight={6}
# Using CV with max_depth={7}, min_child_weight={4}
# Using CV with max_depth={7}, min_child_weight={5}
# Using CV with max_depth={1}, min_child_weight={6}
# Using CV with max_depth={7}, min_child_weight={10}
# New best param found: mlogloss = {1.0535128991813134}, boost_rounds = {1220}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={1}
# Using CV with max_depth={7}, min_child_weight={2}
# Using CV with max_depth={10}, min_child_weight={2}
# Using CV with eta={0.005}, gamma={3.0}
# Using CV with eta={0.05}, gamma={0}
# Using CV with eta={0.05}, gamma={0.5}
# Using CV with eta={0.01}, gamma={0}
# Using CV with eta={0.01}, gamma={0.01}
# Using CV with eta={0.005}, gamma={5.0}
# Using CV with eta={0.01}, gamma={0.001}
# Using CV with eta={0.05}, gamma={10.0}
# Using CV with eta={0.01}, gamma={10.0}
# Using CV with eta={0.05}, gamma={3.0}
# Using CV with eta={0.005}, gamma={10.0}
# Using CV with eta={0.005}, gamma={0}
# Using CV with subsample={0.9}, colsample_bytree={1.0}
# Using CV with subsample={0.9}, colsample_bytree={0.8}
# Using CV with subsample={0.6}, colsample_bytree={0.9}
# Using CV with subsample={0.6}, colsample_bytree={0.8}
# Using CV with subsample={0.9}, colsample_bytree={0.6}
# Using CV with subsample={0.7}, colsample_bytree={0.9}
# Using CV with subsample={0.7}, colsample_bytree={0.6}
# Using CV with max_depth={4}, min_child_weight={10}
# Using CV with max_depth={3}, min_child_weight={5}
# Using CV with max_depth={9}, min_child_weight={0}
# Using CV with max_depth={3}, min_child_weight={3}
# Using CV with max_depth={9}, min_child_weight={1}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={3}, min_child_weight={0}
# Using CV with max_depth={9}, min_child_weight={2}
# Using CV with max_depth={3}, min_child_weight={10}
# Using CV with max_depth={4}, min_child_weight={4}
# Using CV with max_depth={4}, min_child_weight={0}
# Using CV with max_depth={9}, min_child_weight={10}
# New best param found: mlogloss = {1.0529924391137573}, boost_rounds = {1220}
# Using CV with max_depth={9}, min_child_weight={4}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with max_depth={10}, min_child_weight={2}
# Using CV with eta={0.3}, gamma={1.0}
# Using CV with eta={0.3}, gamma={0.5}
# Using CV with eta={0.3}, gamma={0}
# Using CV with eta={0.3}, gamma={0.2}
# Using CV with eta={0.005}, gamma={0.01}
# Using CV with eta={0.3}, gamma={0.01}
# Using CV with eta={0.3}, gamma={0.001}
# Using CV with eta={0.005}, gamma={0}
# Using CV with eta={0.005}, gamma={0.5}
# Using CV with subsample={0.8}, colsample_bytree={1.0}
# Using CV with subsample={0.7}, colsample_bytree={0.7}
# Using CV with subsample={0.8}, colsample_bytree={0.6}
# Using CV with subsample={0.8}, colsample_bytree={0.9}
# Using CV with subsample={1.0}, colsample_bytree={0.5}
# Using CV with subsample={1.0}, colsample_bytree={0.6}
# Using CV with subsample={1.0}, colsample_bytree={0.8}
# Using CV with max_depth={6}, min_child_weight={4}
# Using CV with max_depth={10}, min_child_weight={5}
# Using CV with max_depth={1}, min_child_weight={3}
# Using CV with max_depth={8}, min_child_weight={3}
# Using CV with max_depth={8}, min_child_weight={6}
# Using CV with max_depth={6}, min_child_weight={7}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={8}, min_child_weight={1}
# Using CV with max_depth={10}, min_child_weight={6}
# Using CV with max_depth={8}, min_child_weight={0}
# Using CV with max_depth={8}, min_child_weight={10}
# New best param found: mlogloss = {1.0529129019293526}, boost_rounds = {1220}
# Using CV with max_depth={6}, min_child_weight={0}
# Using CV with max_depth={6}, min_child_weight={10}
# Using CV with max_depth={1}, min_child_weight={6}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={9}
# Using CV with eta={0.05}, gamma={0}
# Using CV with eta={0.005}, gamma={5.0}
# Using CV with eta={0.05}, gamma={0.01}
# Using CV with eta={0.05}, gamma={5.0}
# Using CV with eta={0.005}, gamma={1.0}
# Using CV with eta={0.05}, gamma={3.0}
# Using CV with eta={0.005}, gamma={10.0}
# Using CV with eta={0.005}, gamma={0}
# Using CV with eta={0.005}, gamma={0.5}
# Using CV with subsample={0.5}, colsample_bytree={1.0}
# Using CV with subsample={0.5}, colsample_bytree={0.6}
# Using CV with subsample={0.5}, colsample_bytree={0.7}
# Using CV with max_depth={1}, min_child_weight={2}
# Using CV with max_depth={9}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={4}
# Using CV with max_depth={10}, min_child_weight={10}
# Using CV with max_depth={2}, min_child_weight={8}
# Using CV with max_depth={9}, min_child_weight={8}
# Using CV with max_depth={10}, min_child_weight={6}
# Using CV with max_depth={1}, min_child_weight={4}
# Using CV with max_depth={2}, min_child_weight={10}
# Using CV with max_depth={9}, min_child_weight={10}
# Using CV with max_depth={2}, min_child_weight={0}
# Using CV with max_depth={10}, min_child_weight={1}
# Using CV with max_depth={2}, min_child_weight={2}
# Using CV with max_depth={1}, min_child_weight={10}
# Using CV with max_depth={10}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={0}
# Using CV with max_depth={1}, min_child_weight={1}
# Using CV with eta={0.3}, gamma={0.5}
# Using CV with eta={0.3}, gamma={0}
# Using CV with eta={0.05}, gamma={0}
# Using CV with eta={0.1}, gamma={0}
# Using CV with eta={0.1}, gamma={0.5}
# Using CV with eta={0.3}, gamma={0.01}
# Using CV with eta={0.1}, gamma={5.0}
# Using CV with eta={0.3}, gamma={10.0}
# Using CV with eta={0.05}, gamma={10.0}
# Using CV with eta={0.1}, gamma={3.0}
# Using CV with eta={0.05}, gamma={3.0}

# %%
seed = 1234
np.random.seed(seed)
train_split = 0.7
test_split = 0.5

le = preprocessing.LabelEncoder()
bal_ecm['encoded_target'] = le.fit_transform(bal_ecm[target])
training_bins = np.random.choice(bal_ecm.bins.unique(), int(len(bal_ecm.bins.unique())*train_split), replace=False)
X_train = bal_ecm[bal_ecm.bins.isin(training_bins)]
X_test_val = bal_ecm[~bal_ecm.bins.isin(training_bins)]
X_val, X_test = train_test_split(X_test_val, test_size=test_split, random_state=seed)
y_train = X_train['encoded_target']
y_test = X_test['encoded_target']
y_val = X_val['encoded_target']
dtrain = xgb.DMatrix(X_train[new_feat], label=y_train)
dtest = xgb.DMatrix(X_test[new_feat], label=y_test)
dval = xgb.DMatrix(X_val[new_feat], label=y_val)

# %%
best_param2={'max_depth': 5,
             'eta': 0.005,
             'min_child_weight': 10,
             'verbosity': 0,
             'objective': 'multi:softprob',
             'num_class': 4,
             'silent': 'True',
             'gamma': 5,
             'subsample': 0.6,
             'colsample_bytree': 0.5,
             'eval_metric': 'mlogloss',
             'gpu_id': 0,
             'tree_method': 'gpu_hist',
             'predictor': 'gpu_predictor'}

# %%
evals = [(dtrain, 'train'), (dval, 'eval')]
num_round = best_boost_rounds
bst2 = xgb.train(best_param, dtrain, num_round, evals, early_stopping_rounds=3, )


######
label = dtest.get_label()
ypred1 = bst2.predict(dtest)
# by default, we predict using all the trees
pred2 = [np.where(x == np.max(x))[0][0] for x in ypred1]

print("Accuracy:",metrics.accuracy_score(y_test, pred2))
# Out:
# [0]	train-mlogloss:1.38480	eval-mlogloss:1.38538
# Multiple eval metrics have been passed: 'eval-mlogloss' will be used for early stopping.
#
# [429]	train-mlogloss:0.97690	eval-mlogloss:1.15596
# [430]	train-mlogloss:0.97646	eval-mlogloss:1.15581
# [431]	train-mlogloss:0.97599	eval-mlogloss:1.15561
# [432]	train-mlogloss:0.97555	eval-mlogloss:1.15539
# [433]	train-mlogloss:0.97507	eval-mlogloss:1.15520
# [434]	train-mlogloss:0.97465	eval-mlogloss:1.15509
# [435]	train-mlogloss:0.97425	eval-mlogloss:1.15497
# [436]	train-mlogloss:0.97373	eval-mlogloss:1.15485
# [437]	train-mlogloss:0.97338	eval-mlogloss:1.15478
# [438]	train-mlogloss:0.97296	eval-mlogloss:1.15463
# [439]	train-mlogloss:0.97246	eval-mlogloss:1.15442
# [440]	train-mlogloss:0.97200	eval-mlogloss:1.15426
# [441]	train-mlogloss:0.97160	eval-mlogloss:1.15410
# [442]	train-mlogloss:0.97117	eval-mlogloss:1.15396
# [443]	train-mlogloss:0.97073	eval-mlogloss:1.15386
# [444]	train-mlogloss:0.97029	eval-mlogloss:1.15372
# [445]	train-mlogloss:0.96990	eval-mlogloss:1.15353
# [446]	train-mlogloss:0.96942	eval-mlogloss:1.15331
# [447]	train-mlogloss:0.96893	eval-mlogloss:1.15312
# [448]	train-mlogloss:0.96846	eval-mlogloss:1.15297
# [449]	train-mlogloss:0.96803	eval-mlogloss:1.15281
# [450]	train-mlogloss:0.96764	eval-mlogloss:1.15267
# [451]	train-mlogloss:0.96725	eval-mlogloss:1.15251
# [452]	train-mlogloss:0.96687	eval-mlogloss:1.15235
# [453]	train-mlogloss:0.96649	eval-mlogloss:1.15220
# [454]	train-mlogloss:0.96613	eval-mlogloss:1.15212
# [455]	train-mlogloss:0.96564	eval-mlogloss:1.15200
# [456]	train-mlogloss:0.96524	eval-mlogloss:1.15187
# [457]	train-mlogloss:0.96485	eval-mlogloss:1.15176
# [458]	train-mlogloss:0.96445	eval-mlogloss:1.15166
# [459]	train-mlogloss:0.96406	eval-mlogloss:1.15154
# [460]	train-mlogloss:0.96360	eval-mlogloss:1.15138
# [461]	train-mlogloss:0.96320	eval-mlogloss:1.15131
# [462]	train-mlogloss:0.96278	eval-mlogloss:1.15115
# [463]	train-mlogloss:0.96245	eval-mlogloss:1.15108
# [464]	train-mlogloss:0.96200	eval-mlogloss:1.15094
# [465]	train-mlogloss:0.96162	eval-mlogloss:1.15082
# [466]	train-mlogloss:0.96125	eval-mlogloss:1.15075
# [467]	train-mlogloss:0.96085	eval-mlogloss:1.15063
# [468]	train-mlogloss:0.96045	eval-mlogloss:1.15051
# [469]	train-mlogloss:0.96000	eval-mlogloss:1.15042
# [470]	train-mlogloss:0.95963	eval-mlogloss:1.15037
# [471]	train-mlogloss:0.95919	eval-mlogloss:1.15029
# [472]	train-mlogloss:0.95885	eval-mlogloss:1.15012
# [473]	train-mlogloss:0.95846	eval-mlogloss:1.14994
# [474]	train-mlogloss:0.95800	eval-mlogloss:1.14976
# [475]	train-mlogloss:0.95754	eval-mlogloss:1.14967
# [476]	train-mlogloss:0.95715	eval-mlogloss:1.14952
# [715]	train-mlogloss:0.88353	eval-mlogloss:1.13255
# [716]	train-mlogloss:0.88324	eval-mlogloss:1.13251
# [717]	train-mlogloss:0.88294	eval-mlogloss:1.13252
# [718]	train-mlogloss:0.88270	eval-mlogloss:1.13247
# [719]	train-mlogloss:0.88248	eval-mlogloss:1.13245
# [720]	train-mlogloss:0.88226	eval-mlogloss:1.13244
# [721]	train-mlogloss:0.88205	eval-mlogloss:1.13242
# [722]	train-mlogloss:0.88179	eval-mlogloss:1.13238
# [723]	train-mlogloss:0.88156	eval-mlogloss:1.13239
# [724]	train-mlogloss:0.88134	eval-mlogloss:1.13234
# [725]	train-mlogloss:0.88113	eval-mlogloss:1.13228
# [726]	train-mlogloss:0.88096	eval-mlogloss:1.13230
# [727]	train-mlogloss:0.88073	eval-mlogloss:1.13230
# [728]	train-mlogloss:0.88051	eval-mlogloss:1.13231
# Stopping. Best iteration:
# [725]	train-mlogloss:0.88113	eval-mlogloss:1.13228
#
# Accuracy: 0.5017783857729138

# %%
class_names = ['P14', 'P21', 'P28', 'P35']
class_results = classification_report(y_test, pred2, digits=4, target_names = ['P14', 'P21', 'P28', 'P35'])
print(str(class_results))
# Out:
#               precision    recall  f1-score   support
#
#          P14     0.6306    0.7071    0.6667       898
#          P21     0.4256    0.5091    0.4636       876
#          P28     0.3953    0.2662    0.3181       943
#          P35     0.5202    0.5352    0.5276       938
#
#     accuracy                         0.5018      3655
#    macro avg     0.4929    0.5044    0.4940      3655
# weighted avg     0.4924    0.5018    0.4924      3655

# %%
# param2 = {'max_depth': 2,
#          'eta': 0.005,

#          'min_child_weight': 0,
#          'verbosity': 0,
#          'objective': 'multi:softprob',
#          'num_class': 4,
#          'silent': 'True',
#          'gamma': 5,
#          'subsample': 0.25,
#          'colsample_bytree': 0.3,
#          'colsample_bynode':.5,
#          'reg_alpha': 0}

# %%
from sklearn.metrics import accuracy_score

model_final = XGBClassifier(**param2)
new_feat = np.array(features)[np.array(model.feature_importances_ > t)]
eval_set = [(X_train[new_feat], y_train), (X_test[new_feat], y_test)]
model_final.fit(X_train[new_feat], y_train, verbose=False, eval_set=eval_set, eval_metric=["merror", 'mlogloss'])
y_pred_f = model_final.predict(X_test[new_feat])
accuracy = accuracy_score(y_test, y_pred_f)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
results = model_final.evals_result()
epochs = len(results['validation_0']['merror'])
x_axis = range(0, epochs)

fig, ax = pl.subplots(figsize=(12,12))
ax.plot(x_axis, results['validation_0']['mlogloss'], label='Train')
ax.plot(x_axis, results['validation_1']['mlogloss'], label='Test')
ax.legend()

pl.ylabel('Log Loss')
pl.title('XGBoost Log Loss')
pl.show()

# %%
sorted(dict_importance, key=dict_importance.get, reverse=True)[:5]

# %%
new_feat = np.array(features)[np.array(model.feature_importances_ > best_thresh)]
model2.fit(X_train[new_feat], y_train, verbose=False, eval_set=[(X_val[new_feat],y_val)], eval_metric='mlogloss')
pred3 = model2.predict(X_test[new_feat])
acc = metrics.accuracy_score(y_test, pred3)
print("Accuracy:",metrics.accuracy_score(y_test, pred3))
